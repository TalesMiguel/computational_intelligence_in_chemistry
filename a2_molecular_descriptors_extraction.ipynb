# %% [markdown]
# # **Molecular Descriptor Extraction and Clustering**
#
# - Author: Tales Miguel Machado Pereira
# - RA: 140247
# - Professor: Dr. Marcos Quiles
#
# This notebook extracts 6 key molecular descriptors from SMILES representations and performs clustering analysis using K-Means and DBSCAN algorithms on the QM9 dataset.

# %% [markdown]
# ### **1. Import Libraries**
#
# Import necessary libraries for molecular descriptor calculation and data analysis. Polars is used for optimized data processing where possible, with pandas fallback for RDKit compatibility.

# %%
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

from tqdm.auto import tqdm

# RDKit for molecular descriptors
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, Fragments, Lipinski, Crippen
from rdkit.Chem.rdMolDescriptors import CalcNumRotatableBonds, CalcNumHBD, CalcNumHBA

# Clustering libraries
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, calinski_harabasz_score
import hdbscan

from scipy import stats

# %% [markdown]
# ### **2. Load Molecular Data**
#
# Load the QM9 dataset with SMILES strings from the previously processed data.

# %%
df_pl = pl.read_csv('qm9_complete_dataset.csv')
df = df_pl.to_pandas()  # Convert to pandas for RDKit compatibility

print(f"Dataset loaded with {len(df)} molecules")
print(f"Columns: {list(df.columns)}")

# SMILES Validation
valid_smiles = []
valid_indices = []

for idx, smiles in tqdm(enumerate(df['canonical_smiles']), total=len(df), desc="Validating SMILES"):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        valid_smiles.append(smiles)
        valid_indices.append(idx)

print(f"\nValid SMILES for descriptor calculation: {len(valid_smiles)}/{len(df)}")

# df with valid molecules only
df_valid_pl = df_pl.filter(pl.col('canonical_smiles').is_in(valid_smiles))
df_valid = df_valid_pl.to_pandas().reset_index(drop=True)
df_valid['smiles'] = valid_smiles
# Out:
# Dataset loaded with 133885 molecules
# Columns: ['gdb_id', 'rot_const_A', 'rot_const_B', 'rot_const_C', 'dipole_moment', 'isotropic_polarizability', 'homo_energy', 'lumo_energy', 'homo_lumo_gap', 'electronic_spatial_extent', 'zpve', 'U0', 'U', 'H', 'G', 'Cv', 'n_atoms', 'smiles', 'canonical_smiles']
# Validating SMILES: 100%|██████████| 133885/133885 [00:03<00:00, 40992.38it/s]
# Valid SMILES for descriptor calculation: 133885/133885

# %% [markdown]
# ### **3. Calculate Key Molecular Descriptors**
#
# Calculating 6 molecular descriptors that capture these chemical features: size, lipophilicity, polarity, hydrogen bonding, and flexibility.

# %%
def calculate_key_descriptors(smiles_list):
    """Calculate 6 key molecular descriptors from SMILES (2D only, no geometry)."""
    
    descriptors = []
    
    for smiles in tqdm(smiles_list, desc="Calculating descriptors"):
        mol = Chem.MolFromSmiles(smiles)
        
        if mol is None:
            # Handle invalid SMILES
            desc = {
                'molecular_weight': np.nan,
                'logp': np.nan,
                'tpsa': np.nan,
                'hbd': np.nan,
                'hba': np.nan,
                'rotatable_bonds': np.nan
            }
        else:
            desc = {
                'molecular_weight': Descriptors.MolWt(mol),     # Size
                'logp': Crippen.MolLogP(mol),                   # Lipophilicity
                'tpsa': rdMolDescriptors.CalcTPSA(mol),         # Polarity
                'hbd': CalcNumHBD(mol),                         # Hydrogen-bond donors
                'hba': CalcNumHBA(mol),                         # Hydrogen-bond acceptors
                'rotatable_bonds': CalcNumRotatableBonds(mol)   # Flexibility
            }
        
        descriptors.append(desc)
    
    # Create polars DataFrame for better performance
    descriptors_pl = pl.DataFrame(descriptors)
    return descriptors_pl

print("Calculating 6 key molecular descriptors...")
descriptors_df_pl = calculate_key_descriptors(df_valid['smiles'])
descriptors_df = descriptors_df_pl.to_pandas()  # Convert for compatibility

print(f"\nDescriptors calculated for {len(descriptors_df)} molecules")
print(f"Number of descriptors: {len(descriptors_df.columns)}")
print(f"Descriptor names: {list(descriptors_df.columns)}")

print("\nDescriptor statistics:")
print(descriptors_df.describe().round(3))

# Use polars for efficient data combination
base_cols_pl = df_valid_pl.select(['gdb_id', 'canonical_smiles']).with_columns(
    pl.Series('smiles', df_valid['smiles'])
)
combined_df_pl = pl.concat([base_cols_pl, descriptors_df_pl], how='horizontal')
combined_df = combined_df_pl.to_pandas()

print(f"\nCombined dataset shape: {combined_df.shape}")
print(f"Missing values per descriptor:")
# Use polars for efficient null counting
descriptor_cols = descriptors_df_pl.columns
missing_summary_pl = combined_df_pl.select([pl.col(col).null_count().alias(f"{col}_nulls") for col in descriptor_cols])
missing_dict = {col.replace('_nulls', ''): missing_summary_pl[col][0] for col in missing_summary_pl.columns if missing_summary_pl[col][0] > 0}
for col, count in missing_dict.items():
    print(f"  {col}: {count}")
if not missing_dict:
    print("  No missing values found")
# Out:
# Calculating 6 key molecular descriptors...
# Calculating descriptors: 100%|██████████| 133885/133885 [00:20<00:00, 6377.36it/s]
# Descriptors calculated for 133885 molecules
# Number of descriptors: 6
# Descriptor names: ['molecular_weight', 'logp', 'tpsa', 'hbd', 'hba', 'rotatable_bonds']
#
# Descriptor statistics:
#        molecular_weight        logp        tpsa         hbd         hba  \
# count        133885.000  133885.000  133885.000  133885.000  133885.000
# mean            122.765       0.297      37.164       0.828       2.232
# std               7.565       1.001      21.245       0.838       1.055
# min              16.043      -4.910       0.000       0.000       0.000
# 25%             121.183      -0.349      20.310       0.000       2.000
# 50%             125.127       0.282      35.820       1.000       2.000
# 75%             127.143       0.947      50.620       1.000       3.000
# max             152.037       3.757     130.120       5.000       7.000
#
#        rotatable_bonds
# count       133885.000
# mean             0.923
# std              1.091
# min              0.000
# 25%              0.000
# 50%              1.000
# 75%              1.000
# max              6.000
#
# Combined dataset shape: (133885, 9)
# Missing values per descriptor:
#   No missing values found

# %% [markdown]
# ### **4. Visualize Descriptor Distribution**
#
# Analyze the distribution of the two key molecular descriptors.

# %%
# Get all descriptor columns (excluding ID and SMILES columns)
descriptor_columns = [col for col in combined_df.columns if col not in ['gdb_id', 'smiles', 'canonical_smiles']]

# Use polars for efficient data cleaning
clean_df_pl = combined_df_pl.drop_nulls(subset=descriptor_columns)
clean_df = clean_df_pl.to_pandas().reset_index(drop=True)
print(f"Clean dataset for clustering: {len(clean_df)} molecules")
print(f"Total number of descriptors: {len(descriptor_columns)}")
print(f"Descriptor names: {descriptor_columns}")

# Show some key statistics about the feature space
print(f"\nFeature Space Information:")
print(f"Number of samples (molecules): {len(clean_df)}")
print(f"Number of features (descriptors): {len(descriptor_columns)}")
print(f"Feature vector shape: ({len(clean_df)}, {len(descriptor_columns)})")

# Visualize distributions of key descriptors
key_descriptors = descriptor_columns[:12]  # Show first 12 descriptors
n_descriptors = len(key_descriptors)
n_cols = 4
n_rows = (n_descriptors + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4 * n_rows))
axes = axes.flatten() if n_rows > 1 else axes if n_rows == 1 else [axes]

for i, desc in enumerate(key_descriptors):
    data = clean_df[desc].dropna()
    
    if len(data) > 0:
        axes[i].hist(data, bins=30, alpha=0.7, edgecolor='black')
        axes[i].set_xlabel('Value')
        axes[i].set_ylabel('Frequency')
        axes[i].set_title(f'{desc.replace("_", " ").title()}')
        axes[i].grid(True, alpha=0.3)
        
        # Add mean line
        mean_val = data.mean()
        axes[i].axvline(mean_val, color='red', linestyle='--', alpha=0.7)
    else:
        axes[i].text(0.5, 0.5, 'No data', transform=axes[i].transAxes, ha='center', va='center')
        axes[i].set_title(f'{desc} (No Data)')

# Hide unused subplots
for i in range(len(key_descriptors), len(axes)):
    axes[i].set_visible(False)

plt.suptitle(f'Molecular Descriptor Distributions (First {len(key_descriptors)} of {len(descriptor_columns)})', 
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# Prepare feature matrix for clustering (all descriptors)
feature_matrix = clean_df[descriptor_columns].values
print(f"\nFeature matrix created:")
print(f"  Shape: {feature_matrix.shape}")
print(f"  Data type: {feature_matrix.dtype}")
print(f"  Memory usage: {feature_matrix.nbytes / 1024 / 1024:.2f} MB")

# Show feature ranges
print(f"\nFeature ranges (first 10 descriptors):")
for i, desc in enumerate(descriptor_columns[:10]):
    min_val = clean_df[desc].min()
    max_val = clean_df[desc].max()
    mean_val = clean_df[desc].mean()
    print(f"  {desc}: {min_val:.2f} to {max_val:.2f} (mean: {mean_val:.2f})")

if len(descriptor_columns) > 10:
    print(f"  ... and {len(descriptor_columns) - 10} more descriptors")
# Out:
# Clean dataset for clustering: 133885 molecules
# Total number of descriptors: 6
# Descriptor names: ['molecular_weight', 'logp', 'tpsa', 'hbd', 'hba', 'rotatable_bonds']
#
# Feature Space Information:
# Number of samples (molecules): 133885
# Number of features (descriptors): 6
# Feature vector shape: (133885, 6)
# Feature matrix created:
#   Shape: (133885, 6)
#   Data type: float64
#   Memory usage: 6.13 MB
#
# Feature ranges (first 10 descriptors):
#   molecular_weight: 16.04 to 152.04 (mean: 122.76)
#   logp: -4.91 to 3.76 (mean: 0.30)
#   tpsa: 0.00 to 130.12 (mean: 37.16)
#   hbd: 0.00 to 5.00 (mean: 0.83)
#   hba: 0.00 to 7.00 (mean: 2.23)
#   rotatable_bonds: 0.00 to 6.00 (mean: 0.92)

# %% [markdown]
# ### **5. Data Preparation for Clustering**
#
# Standardize the features for optimal clustering performance.

# %%
# Standardize features for clustering
scaler = StandardScaler()
features_scaled = scaler.fit_transform(feature_matrix)

print("Feature standardization completed")
print(f"Scaled features shape: {features_scaled.shape}")
print(f"\nScaled feature statistics:")
print(f"  Mean: {features_scaled.mean(axis=0)}")
print(f"  Std: {features_scaled.std(axis=0)}")

# Create DataFrame with scaled features for easier handling
scaled_df = clean_df.copy()
scaled_df['logp_scaled'] = features_scaled[:, 0]
scaled_df['tpsa_scaled'] = features_scaled[:, 1]

print("\nData ready for clustering analysis")
# Out:
# Feature standardization completed
# Scaled features shape: (133885, 6)
#
# Scaled feature statistics:
#   Mean: [-1.60656905e-15 -5.43448304e-17 -1.76620699e-16  9.68017291e-17
#   8.49137975e-17 -4.07586228e-17]
#   Std: [1. 1. 1. 1. 1. 1.]
#
# Data ready for clustering analysis

# %% [markdown]
# ### **6. K-Means Clustering**
#
# Apply K-Means clustering algorithm to group molecules based on their descriptors.

# %%
# Perform K-Means clustering with k=2, k=3, and k=5
k_values = [2, 3, 5]
kmeans_results = {}

print("\nPerforming K-Means clustering with different k values:")
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(features_scaled)
    kmeans_results[k] = {
        'model': kmeans,
        'labels': labels,
        'silhouette': silhouette_score(features_scaled, labels)
    }

    unique_clusters, cluster_counts = np.unique(labels, return_counts=True)
    cluster_counts_dict = dict(zip(unique_clusters, cluster_counts))

    print(f"\nK-Means with k={k}:")
    print(f"  Silhouette score: {kmeans_results[k]['silhouette']:.3f}")
    print(f"  Cluster distribution:")
    for cluster, count in cluster_counts_dict.items():
        percentage = (count / len(labels)) * 100
        print(f"    Cluster {cluster}: {count} molecules ({percentage:.1f}%)")

# Plot clustering results for k=2, k=3, and k=5
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, k in enumerate(k_values):
    labels = kmeans_results[k]['labels']
    scatter = axes[i].scatter(scaled_df['logp'], scaled_df['tpsa'], 
                             c=labels, cmap='viridis', alpha=0.6, s=10)
    axes[i].set_xlabel('LogP')
    axes[i].set_ylabel('TPSA')
    axes[i].set_title(f'K-Means Clustering (k={k})\nSilhouette: {kmeans_results[k]["silhouette"]:.3f}')
    axes[i].grid(True, alpha=0.3)
    plt.colorbar(scatter, ax=axes[i], label='Cluster')

plt.suptitle('K-Means Clustering Results Comparison', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# Use k=3 as the final clustering result for further analysis
kmeans_final = kmeans_results[3]['model']
kmeans_labels = kmeans_results[3]['labels']

# Add cluster labels to dataframe
scaled_df['kmeans_cluster'] = kmeans_labels

print(f"\nUsing k=3 for final clustering analysis")
print(f"Final cluster distribution:")
unique_clusters, cluster_counts = np.unique(kmeans_labels, return_counts=True)
cluster_counts_dict = dict(zip(unique_clusters, cluster_counts))
for cluster, count in cluster_counts_dict.items():
    percentage = (count / len(kmeans_labels)) * 100
    print(f"  Cluster {cluster}: {count} molecules ({percentage:.1f}%)")
# Out:
# Performing K-Means clustering with different k values:
#
# K-Means with k=2:
#   Silhouette score: 0.293
#   Cluster distribution:
#     Cluster 0: 76450 molecules (57.1%)
#     Cluster 1: 57435 molecules (42.9%)
#
# K-Means with k=3:
#   Silhouette score: 0.205
#   Cluster distribution:
#     Cluster 0: 59350 molecules (44.3%)
#     Cluster 1: 42544 molecules (31.8%)
#     Cluster 2: 31991 molecules (23.9%)
#
# K-Means with k=5:
#   Silhouette score: 0.235
#   Cluster distribution:
#     Cluster 0: 14067 molecules (10.5%)
#     Cluster 1: 27321 molecules (20.4%)
#     Cluster 2: 20465 molecules (15.3%)
#     Cluster 3: 27925 molecules (20.9%)
#     Cluster 4: 44107 molecules (32.9%)
# Using k=3 for final clustering analysis
# Final cluster distribution:
#   Cluster 0: 59350 molecules (44.3%)
#   Cluster 1: 42544 molecules (31.8%)
#   Cluster 2: 31991 molecules (23.9%)

# %% [markdown]
# ### **7. HDBSCAN Clustering**
#
# Apply HDBSCAN clustering algorithm as a hierarchical density-based alternative approach that better handles varying cluster densities in molecular data.

# %%
# HDBSCAN with Memory Management - Use Sampling Approach
print(f"Original dataset size: {len(features_scaled)} molecules")

# Sample a subset for HDBSCAN (20,000 molecules or 30% of dataset, whichever is smaller)
# HDBSCAN is more memory efficient than DBSCAN but still benefits from sampling on large datasets
sample_size = min(20000, int(0.3 * len(features_scaled)), len(features_scaled))
np.random.seed(42)  # For reproducibility
sample_indices = np.random.choice(len(features_scaled), size=sample_size, replace=False)

# Create sample dataset using polars for efficiency
features_sample = features_scaled[sample_indices]
# Create polars dataframe with row indices and filter
clean_df_with_idx_pl = clean_df_pl.with_row_count('row_idx')
clean_df_sample_pl = clean_df_with_idx_pl.filter(pl.col('row_idx').is_in(sample_indices)).drop('row_idx')
clean_df_sample = clean_df_sample_pl.to_pandas().reset_index(drop=True)

print(f"Sample size for HDBSCAN: {len(features_sample)} molecules")
# Out:
# Original dataset size: 133885 molecules
# Sample size for HDBSCAN: 20000 molecules

# %% [markdown]
# ### **7.1. Sample Representativeness Validation**
#
# Validate that the sample is statistically representative (using Kolmogorov-Smirnov Test) of the full dataset before proceeding with HDBSCAN clustering.

# %%
# Validate sample representativeness
print(f"Sample Quality Assessment:")
print("=" * 40)

# Compare distributions of each descriptor
descriptor_names = ['molecular_weight', 'logp', 'tpsa', 'hbd', 'hba', 'rotatable_bonds']

print("Statistical Comparison (Full Dataset vs Sample):")
print(f"{'Descriptor':<20} {'Full Mean':<12} {'Sample Mean':<12} {'Diff %':<10} {'Full Std':<12} {'Sample Std':<12}")
print("-" * 80)

for i, desc in enumerate(tqdm(descriptor_names, desc="Comparing distributions")):
    full_mean = clean_df[desc].mean()
    sample_mean = clean_df_sample[desc].mean()
    full_std = clean_df[desc].std()
    sample_std = clean_df_sample[desc].std()
    
    # Calculate percentage difference in means
    diff_percent = abs((sample_mean - full_mean) / full_mean) * 100 if full_mean != 0 else 0
    
    print(f"{desc:<20} {full_mean:<12.3f} {sample_mean:<12.3f} {diff_percent:<10.2f} {full_std:<12.3f} {sample_std:<12.3f}")

# Statistical tests for representativeness
print(f"\nKolmogorov-Smirnov Test (p-value > 0.05 = good sample):")
ks_results = []
for desc in tqdm(descriptor_names, desc="KS tests"):
    full_data = clean_df[desc].values
    sample_data = clean_df_sample[desc].values
    
    # KS test: null hypothesis = distributions are the same
    ks_stat, p_value = stats.ks_2samp(full_data, sample_data)
    ks_results.append(p_value)
    
    status = "✓ Good" if p_value > 0.05 else "⚠ Warning"
    print(f"  {desc:<20}: p-value = {p_value:.4f} ({status})")

# Overall assessment
good_samples = sum(1 for p in ks_results if p > 0.05)
total_descriptors = len(ks_results)
sample_quality = good_samples / total_descriptors

print(f"\nSample Quality Summary:")
print(f"  Descriptors with good distribution match: {good_samples}/{total_descriptors}")
print(f"  Sample quality score: {sample_quality:.1%}")

if sample_quality >= 0.8:
    print("  Sample is highly representative of the full dataset")
elif sample_quality >= 0.6:
    print("  Sample is moderately representative")
else:
    print("  Sample may not be representative (consider larger sample)")

# sample vs full distribution
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, desc in enumerate(descriptor_names):
    axes[i].hist(clean_df[desc], bins=50, alpha=0.6, label='Full Dataset', density=True, color='blue')
    axes[i].hist(clean_df_sample[desc], bins=30, alpha=0.8, label='Sample', density=True, color='red')
    axes[i].set_xlabel(desc.replace('_', ' ').title())
    axes[i].set_ylabel('Density')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.suptitle('Distribution Comparison: Full Dataset vs Sample', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Sample Quality Assessment:
# ========================================
# Statistical Comparison (Full Dataset vs Sample):
# Descriptor           Full Mean    Sample Mean  Diff %     Full Std     Sample Std
# --------------------------------------------------------------------------------
# Comparing distributions: 100%|██████████| 6/6 [00:00<00:00, 2261.69it/s]
# Comparing distributions: 100%|██████████| 6/6 [00:00<00:00, 2261.69it/s]
# molecular_weight     122.765      122.717      0.04       7.565        7.634
# logp                 0.297        0.299        0.53       1.001        1.003
# tpsa                 37.164       37.151       0.04       21.245       21.294
# hbd                  0.828        0.826        0.24       0.838        0.840
# hba                  2.232        2.228        0.20       1.055        1.059
# rotatable_bonds      0.923        0.918        0.58       1.091        1.088
#
# Kolmogorov-Smirnov Test (p-value > 0.05 = good sample):
# KS tests: 100%|██████████| 6/6 [00:00<00:00, 201.20it/s]
#   molecular_weight    : p-value = 0.3656 (✓ Good)
#   logp                : p-value = 0.9952 (✓ Good)
#   tpsa                : p-value = 0.8087 (✓ Good)
#   hbd                 : p-value = 0.9999 (✓ Good)
#   hba                 : p-value = 0.9914 (✓ Good)
#   rotatable_bonds     : p-value = 0.9735 (✓ Good)
#
# Sample Quality Summary:
#   Descriptors with good distribution match: 6/6
#   Sample quality score: 100.0%
#   Sample is highly representative of the full dataset

# %% [markdown]
# ### **7.2. HDBSCAN Parameter Optimization**
#
# Optimize HDBSCAN parameters using the validated sample and apply the clustering algorithm.

# %%
# HDBSCAN Parameter Optimization
# HDBSCAN is much simpler - only needs min_cluster_size parameter
min_cluster_sizes = [5, 10, 15, 20, 25, 30]
min_samples_values = [5, 10, 15]  # For noise point detection

best_score = -1
best_params = {}
results = []

print("Optimizing HDBSCAN parameters on sample...")
# Create all parameter combinations for progress bar
param_combinations = [(min_cluster_size, min_samples) for min_cluster_size in min_cluster_sizes for min_samples in min_samples_values]

for min_cluster_size, min_samples in tqdm(param_combinations, desc="HDBSCAN optimization"):
    clusterer = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size, min_samples=min_samples, metric='euclidean')
    labels = clusterer.fit_predict(features_sample)
    
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise = list(labels).count(-1)
    
    if n_clusters > 1:  # Need at least 2 clusters for silhouette score
        try:
            # Only calculate silhouette for non-noise points
            valid_indices = labels != -1
            if np.sum(valid_indices) > 1:
                sil_score = silhouette_score(features_sample[valid_indices], labels[valid_indices])
                results.append({
                    'min_cluster_size': min_cluster_size,
                    'min_samples': min_samples,
                    'n_clusters': n_clusters, 
                    'n_noise': n_noise,
                    'silhouette': sil_score,
                    'cluster_persistence': np.mean(clusterer.cluster_persistence_) if len(clusterer.cluster_persistence_) > 0 else 0
                })
                
                if sil_score > best_score:
                    best_score = sil_score
                    best_params = {'min_cluster_size': min_cluster_size, 'min_samples': min_samples}
        except Exception as e:
            pass

# Display results using polars for better performance
results_df_pl = pl.DataFrame(results)
results_df = results_df_pl.to_pandas()
print(f"\nHDBSCAN parameter optimization results (on sample):")
print(results_df.round(3))

# Apply HDBSCAN with best parameters on SAMPLE ONLY
if best_params:
    print(f"\nBest parameters: min_cluster_size={best_params['min_cluster_size']}, min_samples={best_params['min_samples']}")
    print(f"Best silhouette score: {best_score:.3f}")
    
    hdbscan_final = hdbscan.HDBSCAN(
        min_cluster_size=best_params['min_cluster_size'], 
        min_samples=best_params['min_samples'],
        metric='euclidean'
    )
    hdbscan_labels_sample = hdbscan_final.fit_predict(features_sample)
else: 
    # Fallback parameters
    print(f"\nUsing fallback parameters: min_cluster_size=15, min_samples=10")
    hdbscan_final = hdbscan.HDBSCAN(min_cluster_size=15, min_samples=10, metric='euclidean')
    hdbscan_labels_sample = hdbscan_final.fit_predict(features_sample)

# Create HDBSCAN results for sample only
scaled_df_sample = clean_df_sample.copy()
scaled_df_sample['hdbscan_cluster'] = hdbscan_labels_sample

# Analyze HDBSCAN results on sample
n_clusters_hdbscan = len(set(hdbscan_labels_sample)) - (1 if -1 in hdbscan_labels_sample else 0)
n_noise_hdbscan = list(hdbscan_labels_sample).count(-1)

print(f"\nHDBSCAN clustering results (on sample of {sample_size} molecules):")
print(f"Number of clusters: {n_clusters_hdbscan}")
print(f"Number of noise points: {n_noise_hdbscan}")
print(f"Noise percentage: {(n_noise_hdbscan/len(hdbscan_labels_sample))*100:.1f}%")

# Display cluster persistence scores (HDBSCAN-specific feature)
if hasattr(hdbscan_final, 'cluster_persistence_') and len(hdbscan_final.cluster_persistence_) > 0:
    print(f"Cluster persistence scores: {hdbscan_final.cluster_persistence_.round(3)}")
    print(f"Average cluster persistence: {np.mean(hdbscan_final.cluster_persistence_):.3f}")

if n_clusters_hdbscan > 0:
    # Use numpy for efficient value counting
    unique_clusters, cluster_counts = np.unique(hdbscan_labels_sample, return_counts=True)
    cluster_counts_dict = dict(zip(unique_clusters, cluster_counts))
    print(f"\nCluster distribution:")
    for cluster, count in cluster_counts_dict.items():
        percentage = (count / len(hdbscan_labels_sample)) * 100
        if cluster == -1:
            print(f"  Noise: {count} molecules ({percentage:.1f}%)")
        else:
            print(f"  Cluster {cluster}: {count} molecules ({percentage:.1f}%)")

print(f"\nNote: HDBSCAN was run on a sample of {sample_size} molecules to manage memory usage.")
print("HDBSCAN provides hierarchical clustering with automatic density-based cluster detection.")
# Out:
# Optimizing HDBSCAN parameters on sample...
# HDBSCAN optimization: 100%|██████████| 18/18 [00:37<00:00,  2.10s/it]
# HDBSCAN parameter optimization results (on sample):
#     min_cluster_size  min_samples  n_clusters  n_noise  silhouette  \
# 0                  5            5        1239     5828       0.600
# 1                  5           10         547     6868       0.498
# 2                  5           15         337     6384       0.404
# 3                 10            5         638     5427       0.487
# 4                 10           10         476     6797       0.495
# 5                 10           15         283     6332       0.412
# 6                 15            5         366     3838       0.365
# 7                 15           10         310     5292       0.393
# 8                 15           15         260     6265       0.404
# 9                 20            5         256     3756       0.324
# 10                20           10         217     4962       0.344
# 11                20           15         198     5925       0.370
# 12                25            5         205     3982       0.316
# 13                25           10         177     4810       0.329
# 14                25           15         167     5713       0.354
# 15                30            5         168     3333       0.287
# 16                30           10         152     4129       0.301
# 17                30           15         137     5077       0.317
#
#     cluster_persistence
# 0                 1.000
# 1                 1.000
# 2                 1.000
# 3                 1.000
# 4                 1.000
# 5                 1.000
# 6                 1.000
# 7                 1.000
# 8                 1.000
# 9                 1.000
# 10                1.000
# 11                1.000
# 12                0.012
# 13                0.014
# 14                0.013
# 15                0.002
# 16                0.003
# 17                0.003
#
# Best parameters: min_cluster_size=5, min_samples=5
# Best silhouette score: 0.600
#
# HDBSCAN clustering results (on sample of 20000 molecules):
# Number of clusters: 1239
# Number of noise points: 5828
# Noise percentage: 29.1%
# Cluster persistence scores: [1. 1. 1. ... 1. 1. 1.]
# Average cluster persistence: 1.000
#
# Cluster distribution:
#   Noise: 5828 molecules (29.1%)
#   Cluster 0: 5 molecules (0.0%)
#   Cluster 1: 9 molecules (0.0%)
#   Cluster 2: 9 molecules (0.0%)
#   Cluster 3: 12 molecules (0.1%)
#   Cluster 4: 7 molecules (0.0%)
#   Cluster 5: 7 molecules (0.0%)
#   Cluster 6: 6 molecules (0.0%)
#   Cluster 7: 18 molecules (0.1%)
#   Cluster 8: 6 molecules (0.0%)
#   Cluster 9: 16 molecules (0.1%)
#   Cluster 10: 24 molecules (0.1%)
#   Cluster 11: 15 molecules (0.1%)
#   Cluster 12: 6 molecules (0.0%)
#   Cluster 13: 11 molecules (0.1%)
#   Cluster 14: 7 molecules (0.0%)
#   Cluster 15: 54 molecules (0.3%)
#   Cluster 16: 69 molecules (0.3%)
#   Cluster 17: 28 molecules (0.1%)
#   Cluster 18: 7 molecules (0.0%)
#   Cluster 19: 10 molecules (0.1%)
#   Cluster 20: 10 molecules (0.1%)
#   Cluster 21: 6 molecules (0.0%)
#   Cluster 22: 17 molecules (0.1%)
#   Cluster 23: 15 molecules (0.1%)
#   Cluster 24: 6 molecules (0.0%)
#   Cluster 25: 12 molecules (0.1%)
#   Cluster 26: 6 molecules (0.0%)
#   Cluster 27: 34 molecules (0.2%)
#   Cluster 28: 19 molecules (0.1%)
#   Cluster 29: 27 molecules (0.1%)
#   Cluster 30: 16 molecules (0.1%)
#   Cluster 31: 34 molecules (0.2%)
#   Cluster 32: 8 molecules (0.0%)
#   Cluster 33: 6 molecules (0.0%)
#   Cluster 1229: 7 molecules (0.0%)
#   Cluster 1230: 7 molecules (0.0%)
#   Cluster 1231: 8 molecules (0.0%)
#   Cluster 1232: 15 molecules (0.1%)
#   Cluster 1233: 13 molecules (0.1%)
#   Cluster 1234: 8 molecules (0.0%)
#   Cluster 1235: 5 molecules (0.0%)
#   Cluster 1236: 18 molecules (0.1%)
#   Cluster 1237: 7 molecules (0.0%)
#   Cluster 1238: 7 molecules (0.0%)
#
# Note: HDBSCAN was run on a sample of 20000 molecules to manage memory usage.
# HDBSCAN provides hierarchical clustering with automatic density-based cluster detection.

# %% [markdown]
# ### **8. Clustering Results Visualization and Comparison**
#
# Compare the results of both clustering algorithms and analyze cluster characteristics.

# %%
# Clustering results visualization - Top 3 visualizations
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# 1. K-Means results (full dataset) - Traditional scatter
scatter1 = axes[0].scatter(scaled_df['logp'], scaled_df['tpsa'], 
                          c=scaled_df['kmeans_cluster'], cmap='viridis', 
                          alpha=0.6, s=10)
axes[0].set_xlabel('LogP')
axes[0].set_ylabel('TPSA')
axes[0].set_title('K-Means Clustering (k=3)\nFull Dataset')
axes[0].grid(True, alpha=0.3)
plt.colorbar(scatter1, ax=axes[0], label='Cluster')

# 2. HDBSCAN - Density-based visualization with cluster cores
# Separate noise points from clusters
noise_mask = scaled_df_sample['hdbscan_cluster'] == -1
cluster_mask = scaled_df_sample['hdbscan_cluster'] != -1

# Plot noise points first (gray, small, transparent)
if noise_mask.any():
    axes[1].scatter(scaled_df_sample.loc[noise_mask, 'logp'], 
                   scaled_df_sample.loc[noise_mask, 'tpsa'],
                   c='lightgray', s=8, alpha=0.3, label='Noise', marker='.')

# Plot cluster points with size based on cluster membership strength
if cluster_mask.any():
    unique_clusters = sorted(scaled_df_sample.loc[cluster_mask, 'hdbscan_cluster'].unique())
    colors = plt.cm.Set1(np.linspace(0, 1, len(unique_clusters)))
    
    for i, cluster in enumerate(unique_clusters):
        cluster_points = scaled_df_sample['hdbscan_cluster'] == cluster
        axes[1].scatter(scaled_df_sample.loc[cluster_points, 'logp'],
                       scaled_df_sample.loc[cluster_points, 'tpsa'],
                       c=[colors[i]], s=25, alpha=0.8, 
                       label=f'Cluster {cluster}', edgecolors='black', linewidth=0.5)

axes[1].set_xlabel('LogP')
axes[1].set_ylabel('TPSA')
axes[1].set_title(f'HDBSCAN Clustering\nSample ({sample_size} molecules)')
axes[1].grid(True, alpha=0.3)

# 3. HDBSCAN - Density contour plot
# Create a density plot using KDE
if cluster_mask.any():
    # Plot density contours for each cluster
    from scipy.stats import gaussian_kde
    
    for i, cluster in enumerate(unique_clusters):
        cluster_points = scaled_df_sample['hdbscan_cluster'] == cluster
        if cluster_points.sum() > 10:  # Only plot if enough points
            x_cluster = scaled_df_sample.loc[cluster_points, 'logp'].values
            y_cluster = scaled_df_sample.loc[cluster_points, 'tpsa'].values
            
            # Create density estimation
            try:
                kde = gaussian_kde([x_cluster, y_cluster])
                
                # Create grid for contour
                x_min, x_max = x_cluster.min()-0.5, x_cluster.max()+0.5
                y_min, y_max = y_cluster.min()-5, y_cluster.max()+5
                xx, yy = np.meshgrid(np.linspace(x_min, x_max, 30),
                                   np.linspace(y_min, y_max, 30))
                positions = np.vstack([xx.ravel(), yy.ravel()])
                density = kde(positions).reshape(xx.shape)
                
                # Plot contours
                axes[2].contour(xx, yy, density, colors=[colors[i]], alpha=0.6, linewidths=2)
                axes[2].contourf(xx, yy, density, colors=[colors[i]], alpha=0.2, levels=5)
            except:
                # Fallback to scatter if KDE fails
                axes[2].scatter(x_cluster, y_cluster, c=[colors[i]], s=20, alpha=0.6)

# Add noise points as dots
if noise_mask.any():
    axes[2].scatter(scaled_df_sample.loc[noise_mask, 'logp'], 
                   scaled_df_sample.loc[noise_mask, 'tpsa'],
                   c='gray', s=5, alpha=0.4, marker='.')

axes[2].set_xlabel('LogP')
axes[2].set_ylabel('TPSA')
axes[2].set_title('HDBSCAN Density Regions')
axes[2].grid(True, alpha=0.3)

plt.suptitle('Clustering Algorithm Comparison', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
print("Clustering Algorithm Comparison:")
print("=" * 50)

# K-Means metrics (full dataset)
kmeans_silhouette = silhouette_score(features_scaled, kmeans_labels)
kmeans_calinski = calinski_harabasz_score(features_scaled, kmeans_labels)

print(f"K-Means (k=3) - Full Dataset:")
print(f"  Dataset size: {len(features_scaled)} molecules")
print(f"  Silhouette Score: {kmeans_silhouette:.3f}")
print(f"  Calinski-Harabasz Score: {kmeans_calinski:.3f}")
print(f"  Number of clusters: 3")

# HDBSCAN metrics (sample only)
if n_clusters_hdbscan > 1:
    # Remove noise points for metric calculation
    valid_indices = hdbscan_labels_sample != -1
    if np.sum(valid_indices) > 0:
        hdbscan_silhouette = silhouette_score(features_sample[valid_indices], 
                                           hdbscan_labels_sample[valid_indices])
        hdbscan_calinski = calinski_harabasz_score(features_sample[valid_indices], 
                                                hdbscan_labels_sample[valid_indices])
        print(f"\nHDBSCAN - Sample Dataset:")
        print(f"  Dataset size: {sample_size} molecules (sample)")
        print(f"  Silhouette Score: {hdbscan_silhouette:.3f}")
        print(f"  Calinski-Harabasz Score: {hdbscan_calinski:.3f}")
        print(f"  Number of clusters: {n_clusters_hdbscan}")
        print(f"  Noise points: {n_noise_hdbscan} ({(n_noise_hdbscan/len(hdbscan_labels_sample))*100:.1f}%)")
        if hasattr(hdbscan_final, 'cluster_persistence_') and len(hdbscan_final.cluster_persistence_) > 0:
            print(f"  Average cluster persistence: {np.mean(hdbscan_final.cluster_persistence_):.3f}")
else:
    print(f"\nHDBSCAN: Unable to form valid clusters with current parameters")

print(f"\nCluster Characteristics Analysis:")
print("=" * 50)

# K-Means cluster analysis (full dataset)
print("K-Means Clusters (Full Dataset):")
for cluster in range(3):
    cluster_data = scaled_df[scaled_df['kmeans_cluster'] == cluster]
    print(f"  Cluster {cluster} (n={len(cluster_data)}):")
    print(f"    LogP: {cluster_data['logp'].mean():.2f} ± {cluster_data['logp'].std():.2f}")
    print(f"    TPSA: {cluster_data['tpsa'].mean():.2f} ± {cluster_data['tpsa'].std():.2f}")
    print(f"    Molecular Weight: {cluster_data['molecular_weight'].mean():.1f} ± {cluster_data['molecular_weight'].std():.1f}")

# HDBSCAN cluster analysis (sample)
if n_clusters_hdbscan > 0:
    print(f"\nHDBSCAN Clusters (Sample Dataset):")
    for cluster in sorted(set(hdbscan_labels_sample)):
        cluster_data = scaled_df_sample[scaled_df_sample['hdbscan_cluster'] == cluster]
        if cluster == -1:
            print(f"  Noise points (n={len(cluster_data)}):")
        else:
            print(f"  Cluster {cluster} (n={len(cluster_data)}):")
        print(f"    LogP: {cluster_data['logp'].mean():.2f} ± {cluster_data['logp'].std():.2f}")
        print(f"    TPSA: {cluster_data['tpsa'].mean():.2f} ± {cluster_data['tpsa'].std():.2f}")
        print(f"    Molecular Weight: {cluster_data['molecular_weight'].mean():.1f} ± {cluster_data['molecular_weight'].std():.1f}")

output_file = 'qm9_clustering_results.csv'
scaled_df_pl = pl.from_pandas(scaled_df)
scaled_df_pl.write_csv(output_file)
print(f"\nClustering results exported to: {output_file}")

print(f"\nAnalysis completed successfully!")
print(f"Dataset contains {len(scaled_df)} molecules with molecular descriptors and cluster assignments.")
# Out:
# Clustering Algorithm Comparison:
# ==================================================
# K-Means (k=3) - Full Dataset:
#   Dataset size: 133885 molecules
#   Silhouette Score: 0.205
#   Calinski-Harabasz Score: 48941.846
#   Number of clusters: 3
#
# HDBSCAN - Sample Dataset:
#   Dataset size: 20000 molecules (sample)
#   Silhouette Score: 0.600
#   Calinski-Harabasz Score: 651.476
#   Number of clusters: 1239
#   Noise points: 5828 (29.1%)
#   Average cluster persistence: 1.000
#
# Cluster Characteristics Analysis:
# ==================================================
# K-Means Clusters (Full Dataset):
#   Cluster 0 (n=59350):
#     LogP: 0.34 ± 0.56
#     TPSA: 33.36 ± 10.20
#     Molecular Weight: 123.3 ± 6.3
#   Cluster 1 (n=42544):
#     LogP: -0.61 ± 0.76
#     TPSA: 60.50 ± 14.72
#     Molecular Weight: 125.1 ± 6.1
#   Cluster 2 (n=31991):
#     LogP: 1.43 ± 0.66
#     TPSA: 13.19 ± 9.05
#     Molecular Weight: 118.7 ± 9.6
#
# HDBSCAN Clusters (Sample Dataset):
#   Noise points (n=5828):
#     LogP: 0.28 ± 0.99
#     TPSA: 37.54 ± 21.13
#     Molecular Weight: 122.9 ± 7.6
#   Cluster 0 (n=5):
#     LogP: -0.20 ± 0.75
#     TPSA: 37.96 ± 11.36
#     Molecular Weight: 122.5 ± 6.7
#   Cluster 1 (n=9):
#     LogP: 0.55 ± 1.01
#     TPSA: 34.52 ± 17.26
#     Molecular Weight: 123.2 ± 4.1
#   Cluster 2 (n=9):
#     LogP: 1.16 ± 0.78
#     TPSA: 24.87 ± 15.66
#     Molecular Weight: 124.5 ± 2.6
#   Cluster 3 (n=12):
#     LogP: 0.03 ± 1.41
#     TPSA: 34.31 ± 27.33
#     Molecular Weight: 124.6 ± 3.2
#   Cluster 4 (n=7):
#     LogP: 0.09 ± 0.43
#     TPSA: 49.19 ± 19.81
#     Molecular Weight: 123.3 ± 6.5
#   Cluster 5 (n=7):
#     LogP: 0.18 ± 0.87
#     TPSA: 40.17 ± 21.67
#     Molecular Weight: 124.9 ± 3.2
#   Cluster 6 (n=6):
#     LogP: 0.24 ± 0.81
#     TPSA: 32.61 ± 16.29
#     Molecular Weight: 122.8 ± 8.0
#   Cluster 7 (n=18):
#     LogP: 0.14 ± 1.05
#     TPSA: 39.39 ± 23.90
#     Molecular Weight: 123.4 ± 7.9
#   Cluster 8 (n=6):
#     LogP: 0.40 ± 0.75
#     TPSA: 40.64 ± 16.81
#     Molecular Weight: 119.8 ± 5.7
#   Cluster 9 (n=16):
#     LogP: 0.34 ± 1.16
#     TPSA: 31.68 ± 22.97
#     Molecular Weight: 121.8 ± 7.5
#   Cluster 10 (n=24):
#     LogP: 0.14 ± 1.01
#     TPSA: 40.64 ± 22.60
#     Molecular Weight: 122.7 ± 5.6
#   Cluster 11 (n=15):
#     LogP: 0.36 ± 0.81
#     TPSA: 30.51 ± 13.80
#     Molecular Weight: 124.9 ± 5.9
#   Cluster 12 (n=6):
#     LogP: 0.66 ± 1.17
#     TPSA: 23.59 ± 15.97
#     Molecular Weight: 125.0 ± 2.6
#   Cluster 13 (n=11):
#     LogP: 0.53 ± 1.36
#     TPSA: 28.51 ± 19.11
#     Molecular Weight: 122.3 ± 5.6
#   Cluster 14 (n=7):
#     LogP: 0.80 ± 0.75
#     TPSA: 27.11 ± 22.45
#     Molecular Weight: 123.0 ± 7.7
#   Cluster 15 (n=54):
#     LogP: 0.38 ± 0.85
#     TPSA: 38.81 ± 19.86
#     Molecular Weight: 121.4 ± 8.3
#   Cluster 16 (n=69):
#     LogP: 0.32 ± 1.15
#     TPSA: 37.36 ± 20.13
#     Molecular Weight: 123.2 ± 5.7
#   Cluster 17 (n=28):
#     LogP: 0.27 ± 0.90
#     TPSA: 39.82 ± 21.33
#     Molecular Weight: 124.9 ± 4.7
#   Cluster 18 (n=7):
#     LogP: 0.81 ± 0.69
#     TPSA: 30.84 ± 21.08
#     Molecular Weight: 120.6 ± 5.3
#   Cluster 19 (n=10):
#     LogP: 0.68 ± 1.19
#     TPSA: 27.84 ± 20.41
#     Molecular Weight: 121.0 ± 6.5
#   Cluster 20 (n=10):
#     LogP: -0.17 ± 0.78
#     TPSA: 51.43 ± 29.56
#     Molecular Weight: 124.1 ± 5.2
#   Cluster 21 (n=6):
#     LogP: 0.57 ± 0.53
#     TPSA: 34.00 ± 13.35
#     Molecular Weight: 124.2 ± 9.2
#   Cluster 22 (n=17):
#     LogP: 0.30 ± 0.55
#     TPSA: 34.26 ± 14.38
#     Molecular Weight: 122.6 ± 4.6
#   Cluster 23 (n=15):
#     LogP: 0.38 ± 1.17
#     TPSA: 33.05 ± 20.07
#     Molecular Weight: 123.8 ± 4.0
#   Cluster 24 (n=6):
#     LogP: 0.52 ± 1.05
#     TPSA: 28.67 ± 11.33
#     Molecular Weight: 123.2 ± 6.8
#   Cluster 25 (n=12):
#     LogP: 0.44 ± 0.89
#     TPSA: 40.95 ± 21.16
#     Molecular Weight: 122.9 ± 6.0
#   Cluster 26 (n=6):
#     LogP: -0.03 ± 1.10
#     TPSA: 46.28 ± 20.74
#     Molecular Weight: 117.6 ± 11.6
#   Cluster 27 (n=34):
#     LogP: 0.24 ± 1.01
#     TPSA: 36.68 ± 20.16
#     Molecular Weight: 124.0 ± 5.2
#   Cluster 28 (n=19):
#     LogP: 0.34 ± 0.89
#     TPSA: 34.07 ± 21.06
#     Molecular Weight: 122.2 ± 8.6
#   Cluster 29 (n=27):
#     LogP: 0.46 ± 0.91
#     TPSA: 32.28 ± 20.01
#     Molecular Weight: 123.1 ± 7.1
#   Cluster 30 (n=16):
#     LogP: 0.43 ± 1.12
#     TPSA: 30.64 ± 18.98
#     Molecular Weight: 122.9 ± 4.7
#   Cluster 31 (n=34):
#     LogP: 0.32 ± 1.14
#     TPSA: 35.85 ± 22.33
#     Molecular Weight: 122.5 ± 8.5
#   Cluster 32 (n=8):
#     LogP: -0.16 ± 1.35
#     TPSA: 29.96 ± 22.40
#     Molecular Weight: 121.3 ± 7.4
#   Cluster 33 (n=6):
#     LogP: -0.20 ± 1.23
#     TPSA: 42.05 ± 22.05
#     Molecular Weight: 124.6 ± 6.2
#   Cluster 34 (n=6):
#     LogP: 0.72 ± 0.97
#     TPSA: 34.30 ± 19.24
#     Molecular Weight: 126.3 ± 4.4
#   Cluster 35 (n=8):
#     LogP: -0.16 ± 0.58
#     TPSA: 28.34 ± 11.80
#     Molecular Weight: 122.2 ± 7.5
#   Cluster 36 (n=11):
#     LogP: 0.01 ± 1.02
#     TPSA: 42.52 ± 27.28
#     Molecular Weight: 118.4 ± 12.3
#   Cluster 37 (n=52):
#     LogP: 0.31 ± 0.89
#     TPSA: 37.90 ± 17.53
#     Molecular Weight: 121.9 ± 9.0
#   Cluster 38 (n=107):
#     LogP: 0.31 ± 0.87
#     TPSA: 38.12 ± 18.87
#     Molecular Weight: 123.0 ± 7.6
#   Cluster 39 (n=14):
#     LogP: 0.37 ± 1.07
#     TPSA: 43.06 ± 23.91
#     Molecular Weight: 119.4 ± 11.2
#   Cluster 40 (n=69):
#     LogP: -0.02 ± 0.97
#     TPSA: 39.19 ± 23.26
#     Molecular Weight: 122.0 ± 8.5
#   Cluster 41 (n=11):
#     LogP: 0.69 ± 1.18
#     TPSA: 28.30 ± 20.41
#     Molecular Weight: 124.0 ± 5.8
#   Cluster 42 (n=6):
#     LogP: 0.56 ± 1.39
#     TPSA: 31.08 ± 24.62
#     Molecular Weight: 120.7 ± 11.2
#   Cluster 43 (n=12):
#     LogP: 0.09 ± 0.92
#     TPSA: 36.79 ± 16.44
#     Molecular Weight: 124.8 ± 6.6
#   Cluster 44 (n=8):
#     LogP: -0.22 ± 1.61
#     TPSA: 48.48 ± 24.24
#     Molecular Weight: 125.4 ± 5.6
#   Cluster 45 (n=12):
#     LogP: 0.04 ± 0.65
#     TPSA: 38.67 ± 17.88
#     Molecular Weight: 124.2 ± 7.5
#   Cluster 46 (n=13):
#     LogP: 0.38 ± 0.99
#     TPSA: 34.35 ± 21.20
#     Molecular Weight: 123.8 ± 5.0
#   Cluster 47 (n=8):
#     LogP: -0.30 ± 0.93
#     TPSA: 48.83 ± 15.90
#     Molecular Weight: 123.0 ± 5.4
#   Cluster 48 (n=14):
#     LogP: 0.29 ± 1.01
#     TPSA: 37.13 ± 21.75
#     Molecular Weight: 121.6 ± 8.1
#   Cluster 49 (n=9):
#     LogP: 0.11 ± 0.72
#     TPSA: 36.04 ± 15.44
#     Molecular Weight: 121.3 ± 8.0
#   Cluster 50 (n=8):
#     LogP: -0.04 ± 0.59
#     TPSA: 36.04 ± 9.94
#     Molecular Weight: 121.0 ± 9.1
#   Cluster 51 (n=15):
#     LogP: 0.57 ± 1.04
#     TPSA: 33.42 ± 16.60
#     Molecular Weight: 119.9 ± 12.3
#   Cluster 52 (n=6):
#     LogP: 0.68 ± 1.16
#     TPSA: 33.20 ± 29.09
#     Molecular Weight: 117.3 ± 12.0
#   Cluster 53 (n=10):
#     LogP: 0.29 ± 0.88
#     TPSA: 48.46 ± 27.88
#     Molecular Weight: 123.9 ± 5.1
#   Cluster 54 (n=19):
#     LogP: 0.18 ± 1.50
#     TPSA: 39.86 ± 25.73
#     Molecular Weight: 123.8 ± 5.3
#   Cluster 55 (n=9):
#     LogP: 0.27 ± 0.97
#     TPSA: 31.44 ± 15.89
#     Molecular Weight: 124.9 ± 2.6
#   Cluster 56 (n=20):
#     LogP: 0.63 ± 0.84
#     TPSA: 34.19 ± 16.96
#     Molecular Weight: 123.7 ± 5.8
#   Cluster 57 (n=14):
#     LogP: 0.48 ± 1.00
#     TPSA: 33.29 ± 19.01
#     Molecular Weight: 120.4 ± 9.7
#   Cluster 58 (n=13):
#     LogP: 0.44 ± 1.45
#     TPSA: 39.25 ± 28.25
#     Molecular Weight: 128.0 ± 4.5
#   Cluster 59 (n=8):
#     LogP: 0.46 ± 0.61
#     TPSA: 30.08 ± 16.65
#     Molecular Weight: 123.9 ± 3.1
#   Cluster 60 (n=39):
#     LogP: 0.50 ± 1.11
#     TPSA: 37.01 ± 24.57
#     Molecular Weight: 121.9 ± 8.4
#   Cluster 61 (n=16):
#     LogP: 0.15 ± 1.01
#     TPSA: 37.18 ± 23.87
#     Molecular Weight: 123.7 ± 4.1
#   Cluster 62 (n=13):
#     LogP: 0.32 ± 1.35
#     TPSA: 42.08 ± 26.09
#     Molecular Weight: 125.9 ± 4.7
#   Cluster 63 (n=7):
#     LogP: 1.01 ± 1.30
#     TPSA: 20.78 ± 15.51
#     Molecular Weight: 120.2 ± 8.6
#   Cluster 64 (n=14):
#     LogP: 0.27 ± 0.82
#     TPSA: 42.05 ± 17.59
#     Molecular Weight: 115.2 ± 12.8
#   Cluster 65 (n=12):
#     LogP: 0.53 ± 1.03
#     TPSA: 31.57 ± 24.03
#     Molecular Weight: 120.0 ± 10.0
#   Cluster 66 (n=27):
#     LogP: 0.20 ± 0.92
#     TPSA: 39.15 ± 23.20
#     Molecular Weight: 124.2 ± 4.4
#   Cluster 67 (n=7):
#     LogP: 0.73 ± 0.37
#     TPSA: 26.57 ± 15.39
#     Molecular Weight: 121.2 ± 6.4
#   Cluster 68 (n=6):
#     LogP: 0.33 ± 1.04
#     TPSA: 36.41 ± 17.07
#     Molecular Weight: 125.7 ± 2.1
#   Cluster 69 (n=12):
#     LogP: 0.66 ± 1.03
#     TPSA: 32.88 ± 22.23
#     Molecular Weight: 121.7 ± 7.4
#   Cluster 70 (n=8):
#     LogP: 0.08 ± 0.91
#     TPSA: 47.62 ± 25.87
#     Molecular Weight: 124.0 ± 5.1
#   Cluster 71 (n=8):
#     LogP: 0.95 ± 0.75
#     TPSA: 29.66 ± 15.19
#     Molecular Weight: 123.9 ± 5.6
#   Cluster 72 (n=13):
#     LogP: 0.46 ± 1.06
#     TPSA: 25.91 ± 19.15
#     Molecular Weight: 119.2 ± 8.9
#   Cluster 73 (n=7):
#     LogP: 0.51 ± 1.42
#     TPSA: 36.38 ± 11.43
#     Molecular Weight: 127.0 ± 3.7
#   Cluster 74 (n=8):
#     LogP: 0.11 ± 1.29
#     TPSA: 37.33 ± 18.79
#     Molecular Weight: 122.0 ± 8.6
#   Cluster 75 (n=7):
#     LogP: -0.18 ± 0.99
#     TPSA: 35.49 ± 28.80
#     Molecular Weight: 122.1 ± 9.6
#   Cluster 76 (n=8):
#     LogP: 0.15 ± 0.64
#     TPSA: 49.82 ± 27.61
#     Molecular Weight: 124.1 ± 4.3
#   Cluster 77 (n=7):
#     LogP: 0.45 ± 0.70
#     TPSA: 27.85 ± 11.68
#     Molecular Weight: 118.0 ± 8.6
#   Cluster 78 (n=6):
#     LogP: -0.25 ± 0.71
#     TPSA: 46.39 ± 21.66
#     Molecular Weight: 125.0 ± 6.1
#   Cluster 79 (n=6):
#     LogP: 0.65 ± 0.91
#     TPSA: 26.32 ± 8.80
#     Molecular Weight: 115.1 ± 12.0
#   Cluster 80 (n=31):
#     LogP: 0.05 ± 1.13
#     TPSA: 44.18 ± 21.59
#     Molecular Weight: 125.2 ± 5.7
#   Cluster 81 (n=12):
#     LogP: 0.04 ± 0.65
#     TPSA: 32.87 ± 16.36
#     Molecular Weight: 118.6 ± 9.3
#   Cluster 82 (n=7):
#     LogP: 0.63 ± 0.53
#     TPSA: 36.94 ± 16.70
#     Molecular Weight: 117.4 ± 7.8
#   Cluster 83 (n=15):
#     LogP: 0.48 ± 1.13
#     TPSA: 38.78 ± 20.99
#     Molecular Weight: 124.6 ± 4.9
#   Cluster 84 (n=32):
#     LogP: 0.02 ± 0.88
#     TPSA: 39.77 ± 20.54
#     Molecular Weight: 120.3 ± 20.8
#   Cluster 85 (n=10):
#     LogP: 0.21 ± 1.11
#     TPSA: 40.69 ± 24.33
#     Molecular Weight: 121.2 ± 7.4
#   Cluster 86 (n=14):
#     LogP: -0.31 ± 1.35
#     TPSA: 42.49 ± 25.91
#     Molecular Weight: 123.1 ± 7.6
#   Cluster 87 (n=8):
#     LogP: -0.52 ± 1.75
#     TPSA: 36.15 ± 21.70
#     Molecular Weight: 123.3 ± 5.3
#   Cluster 88 (n=7):
#     LogP: 0.50 ± 0.52
#     TPSA: 26.93 ± 10.35
#     Molecular Weight: 120.9 ± 8.3
#   Cluster 89 (n=6):
#     LogP: 0.18 ± 1.26
#     TPSA: 27.72 ± 25.79
#     Molecular Weight: 114.1 ± 18.8
#   Cluster 90 (n=13):
#     LogP: 0.69 ± 0.78
#     TPSA: 33.95 ± 21.50
#     Molecular Weight: 119.6 ± 12.7
#   Cluster 91 (n=6):
#     LogP: 0.32 ± 1.03
#     TPSA: 35.68 ± 20.21
#     Molecular Weight: 116.8 ± 9.6
#   Cluster 92 (n=8):
#     LogP: -0.03 ± 0.70
#     TPSA: 52.51 ± 17.49
#     Molecular Weight: 125.0 ± 5.3
#   Cluster 93 (n=16):
#     LogP: 0.24 ± 0.83
#     TPSA: 33.16 ± 16.56
#     Molecular Weight: 123.0 ± 6.7
#   Cluster 94 (n=18):
#     LogP: 0.20 ± 0.60
#     TPSA: 38.78 ± 17.97
#     Molecular Weight: 124.8 ± 5.9
#   Cluster 95 (n=6):
#     LogP: 0.28 ± 0.27
#     TPSA: 35.06 ± 18.63
#     Molecular Weight: 125.2 ± 2.9
#   Cluster 96 (n=35):
#     LogP: 0.34 ± 0.94
#     TPSA: 40.12 ± 23.56
#     Molecular Weight: 122.8 ± 7.5
#   Cluster 97 (n=7):
#     LogP: 0.04 ± 0.71
#     TPSA: 43.31 ± 23.52
#     Molecular Weight: 123.7 ± 2.4
#   Cluster 98 (n=10):
#     LogP: 0.53 ± 1.43
#     TPSA: 27.53 ± 21.11
#     Molecular Weight: 121.5 ± 12.6
#   Cluster 99 (n=13):
#     LogP: 0.41 ± 0.75
#     TPSA: 37.36 ± 12.49
#     Molecular Weight: 122.2 ± 7.8
#   Cluster 100 (n=14):
#     LogP: 0.31 ± 0.94
#     TPSA: 35.65 ± 23.40
#     Molecular Weight: 124.6 ± 3.9
#   Cluster 101 (n=15):
#     LogP: 1.03 ± 0.83
#     TPSA: 29.86 ± 19.45
#     Molecular Weight: 123.2 ± 6.2
#   Cluster 102 (n=20):
#     LogP: 0.37 ± 0.88
#     TPSA: 32.15 ± 21.71
#     Molecular Weight: 123.6 ± 6.9
#   Cluster 103 (n=16):
#     LogP: 0.09 ± 0.61
#     TPSA: 38.91 ± 19.53
#     Molecular Weight: 123.6 ± 6.0
#   Cluster 104 (n=5):
#     LogP: 0.09 ± 0.80
#     TPSA: 35.69 ± 24.33
#     Molecular Weight: 122.2 ± 6.6
#   Cluster 105 (n=7):
#     LogP: 0.09 ± 1.17
#     TPSA: 41.37 ± 34.23
#     Molecular Weight: 119.7 ± 9.8
#   Cluster 106 (n=13):
#     LogP: 0.28 ± 1.36
#     TPSA: 46.28 ± 35.61
#     Molecular Weight: 119.9 ± 7.6
#   Cluster 107 (n=9):
#     LogP: 0.67 ± 0.85
#     TPSA: 29.33 ± 21.18
#     Molecular Weight: 124.9 ± 3.5
#   Cluster 108 (n=7):
#     LogP: 0.49 ± 0.78
#     TPSA: 31.76 ± 22.50
#     Molecular Weight: 115.3 ± 16.3
#   Cluster 109 (n=14):
#     LogP: 0.45 ± 0.82
#     TPSA: 35.39 ± 15.95
#     Molecular Weight: 123.1 ± 8.7
#   Cluster 110 (n=10):
#     LogP: 0.50 ± 0.84
#     TPSA: 38.97 ± 26.15
#     Molecular Weight: 121.0 ± 6.1
#   Cluster 111 (n=10):
#     LogP: -0.58 ± 0.98
#     TPSA: 49.30 ± 17.35
#     Molecular Weight: 126.1 ± 2.5
#   Cluster 112 (n=12):
#     LogP: -0.10 ± 1.07
#     TPSA: 41.64 ± 20.98
#     Molecular Weight: 123.9 ± 5.7
#   Cluster 113 (n=11):
#     LogP: 0.44 ± 0.88
#     TPSA: 35.16 ± 27.75
#     Molecular Weight: 123.8 ± 3.5
#   Cluster 114 (n=7):
#     LogP: 0.50 ± 0.81
#     TPSA: 40.34 ± 18.14
#     Molecular Weight: 126.3 ± 1.9
#   Cluster 115 (n=5):
#     LogP: -0.04 ± 1.04
#     TPSA: 35.03 ± 21.82
#     Molecular Weight: 121.3 ± 6.2
#   Cluster 116 (n=13):
#     LogP: 0.70 ± 0.85
#     TPSA: 22.63 ± 15.92
#     Molecular Weight: 117.4 ± 10.7
#   Cluster 117 (n=8):
#     LogP: -0.21 ± 1.71
#     TPSA: 40.92 ± 24.49
#     Molecular Weight: 124.1 ± 2.9
#   Cluster 118 (n=9):
#     LogP: 0.71 ± 1.03
#     TPSA: 31.00 ± 21.77
#     Molecular Weight: 123.4 ± 5.9
#   Cluster 119 (n=6):
#     LogP: 0.83 ± 0.83
#     TPSA: 23.10 ± 20.65
#     Molecular Weight: 115.3 ± 17.1
#   Cluster 120 (n=9):
#     LogP: -0.38 ± 0.77
#     TPSA: 41.99 ± 23.56
#     Molecular Weight: 123.9 ± 5.1
#   Cluster 121 (n=10):
#     LogP: 0.31 ± 0.96
#     TPSA: 37.61 ± 14.73
#     Molecular Weight: 120.5 ± 7.9
#   Cluster 122 (n=6):
#     LogP: 0.49 ± 0.66
#     TPSA: 35.07 ± 20.86
#     Molecular Weight: 127.6 ± 4.7
#   Cluster 123 (n=13):
#     LogP: 0.30 ± 1.10
#     TPSA: 34.93 ± 24.25
#     Molecular Weight: 123.4 ± 4.1
#   Cluster 124 (n=43):
#     LogP: 0.30 ± 1.14
#     TPSA: 40.41 ± 26.83
#     Molecular Weight: 123.0 ± 6.8
#   Cluster 125 (n=6):
#     LogP: 0.34 ± 0.81
#     TPSA: 43.17 ± 20.37
#     Molecular Weight: 125.5 ± 5.6
#   Cluster 126 (n=14):
#     LogP: 0.19 ± 0.72
#     TPSA: 44.41 ± 26.24
#     Molecular Weight: 119.4 ± 8.6
#   Cluster 127 (n=6):
#     LogP: -0.40 ± 1.28
#     TPSA: 55.81 ± 22.49
#     Molecular Weight: 124.0 ± 6.6
#   Cluster 128 (n=8):
#     LogP: 0.11 ± 1.15
#     TPSA: 49.25 ± 33.44
#     Molecular Weight: 122.8 ± 6.5
#   Cluster 129 (n=7):
#     LogP: 0.07 ± 1.16
#     TPSA: 43.86 ± 17.88
#     Molecular Weight: 123.3 ± 7.0
#   Cluster 130 (n=7):
#     LogP: 0.75 ± 1.20
#     TPSA: 31.91 ± 20.79
#     Molecular Weight: 122.9 ± 4.4
#   Cluster 131 (n=7):
#     LogP: 0.43 ± 1.10
#     TPSA: 39.62 ± 15.46
#     Molecular Weight: 122.7 ± 7.5
#   Cluster 132 (n=6):
#     LogP: -0.04 ± 1.04
#     TPSA: 46.20 ± 21.89
#     Molecular Weight: 123.5 ± 5.9
#   Cluster 133 (n=12):
#     LogP: 0.15 ± 0.96
#     TPSA: 41.39 ± 16.16
#     Molecular Weight: 121.1 ± 11.4
#   Cluster 134 (n=7):
#     LogP: 0.97 ± 0.73
#     TPSA: 28.84 ± 20.24
#     Molecular Weight: 118.3 ± 9.0
#   Cluster 135 (n=7):
#     LogP: 0.27 ± 1.20
#     TPSA: 33.59 ± 15.58
#     Molecular Weight: 123.4 ± 5.8
#   Cluster 136 (n=6):
#     LogP: 0.05 ± 0.74
#     TPSA: 46.95 ± 15.57
#     Molecular Weight: 122.8 ± 6.4
#   Cluster 137 (n=11):
#     LogP: -0.06 ± 0.90
#     TPSA: 45.03 ± 20.00
#     Molecular Weight: 118.4 ± 12.2
#   Cluster 138 (n=16):
#     LogP: 0.58 ± 0.95
#     TPSA: 33.64 ± 24.99
#     Molecular Weight: 121.6 ± 10.4
#   Cluster 139 (n=6):
#     LogP: -0.16 ± 0.95
#     TPSA: 41.31 ± 14.99
#     Molecular Weight: 120.0 ± 6.9
#   Cluster 140 (n=6):
#     LogP: 0.12 ± 0.91
#     TPSA: 26.63 ± 12.20
#     Molecular Weight: 120.2 ± 9.3
#   Cluster 141 (n=9):
#     LogP: 0.34 ± 0.80
#     TPSA: 36.28 ± 16.08
#     Molecular Weight: 119.7 ± 12.5
#   Cluster 142 (n=10):
#     LogP: 0.32 ± 0.62
#     TPSA: 41.13 ± 28.12
#     Molecular Weight: 118.4 ± 8.8
#   Cluster 143 (n=6):
#     LogP: 0.37 ± 0.84
#     TPSA: 36.52 ± 11.90
#     Molecular Weight: 126.2 ± 4.1
#   Cluster 144 (n=15):
#     LogP: 0.46 ± 1.00
#     TPSA: 35.09 ± 24.51
#     Molecular Weight: 121.2 ± 8.1
#   Cluster 145 (n=10):
#     LogP: 0.36 ± 0.55
#     TPSA: 33.82 ± 15.96
#     Molecular Weight: 120.6 ± 7.1
#   Cluster 146 (n=18):
#     LogP: 0.33 ± 1.31
#     TPSA: 34.60 ± 23.51
#     Molecular Weight: 122.2 ± 12.1
#   Cluster 147 (n=7):
#     LogP: 0.50 ± 1.42
#     TPSA: 32.38 ± 31.75
#     Molecular Weight: 115.3 ± 25.9
#   Cluster 148 (n=8):
#     LogP: 0.15 ± 1.34
#     TPSA: 34.32 ± 17.61
#     Molecular Weight: 125.0 ± 8.8
#   Cluster 149 (n=15):
#     LogP: 0.42 ± 1.01
#     TPSA: 33.35 ± 15.07
#     Molecular Weight: 122.4 ± 6.4
#   Cluster 150 (n=9):
#     LogP: -0.17 ± 0.99
#     TPSA: 44.56 ± 22.23
#     Molecular Weight: 124.6 ± 4.7
#   Cluster 151 (n=8):
#     LogP: 0.15 ± 1.00
#     TPSA: 42.94 ± 31.95
#     Molecular Weight: 123.8 ± 4.9
#   Cluster 152 (n=21):
#     LogP: 0.31 ± 0.68
#     TPSA: 40.41 ± 19.17
#     Molecular Weight: 122.5 ± 9.3
#   Cluster 153 (n=8):
#     LogP: -0.06 ± 1.51
#     TPSA: 48.91 ± 24.12
#     Molecular Weight: 125.9 ± 4.4
#   Cluster 154 (n=8):
#     LogP: 0.45 ± 1.41
#     TPSA: 39.22 ± 28.99
#     Molecular Weight: 128.5 ± 3.6
#   Cluster 155 (n=15):
#     LogP: 0.22 ± 0.77
#     TPSA: 34.60 ± 13.85
#     Molecular Weight: 122.2 ± 10.6
#   Cluster 156 (n=35):
#     LogP: 0.29 ± 1.17
#     TPSA: 34.52 ± 22.20
#     Molecular Weight: 122.8 ± 7.0
#   Cluster 157 (n=8):
#     LogP: 0.86 ± 1.03
#     TPSA: 21.08 ± 12.34
#     Molecular Weight: 120.5 ± 6.6
#   Cluster 158 (n=19):
#     LogP: -0.09 ± 0.94
#     TPSA: 45.35 ± 20.82
#     Molecular Weight: 123.6 ± 5.6
#   Cluster 159 (n=17):
#     LogP: 0.67 ± 1.33
#     TPSA: 32.45 ± 25.69
#     Molecular Weight: 122.0 ± 6.5
#   Cluster 160 (n=9):
#     LogP: 0.04 ± 1.02
#     TPSA: 38.97 ± 25.63
#     Molecular Weight: 124.6 ± 6.1
#   Cluster 161 (n=17):
#     LogP: 0.27 ± 1.14
#     TPSA: 34.76 ± 13.73
#     Molecular Weight: 123.2 ± 7.9
#   Cluster 162 (n=6):
#     LogP: 0.35 ± 0.91
#     TPSA: 28.58 ± 9.42
#     Molecular Weight: 120.5 ± 11.3
#   Cluster 163 (n=8):
#     LogP: 0.25 ± 1.54
#     TPSA: 38.87 ± 26.11
#     Molecular Weight: 118.0 ± 11.4
#   Cluster 164 (n=6):
#     LogP: -0.32 ± 0.62
#     TPSA: 42.49 ± 10.98
#     Molecular Weight: 120.5 ± 13.1
#   Cluster 165 (n=17):
#     LogP: 0.42 ± 1.25
#     TPSA: 35.37 ± 20.99
#     Molecular Weight: 122.3 ± 7.7
#   Cluster 166 (n=9):
#     LogP: 0.39 ± 1.02
#     TPSA: 31.91 ± 15.11
#     Molecular Weight: 126.4 ± 2.1
#   Cluster 167 (n=6):
#     LogP: 0.42 ± 0.94
#     TPSA: 27.16 ± 18.81
#     Molecular Weight: 124.7 ± 3.0
#   Cluster 168 (n=141):
#     LogP: 0.30 ± 0.98
#     TPSA: 36.15 ± 21.87
#     Molecular Weight: 122.2 ± 8.1
#   Cluster 169 (n=6):
#     LogP: -0.02 ± 0.27
#     TPSA: 52.31 ± 21.07
#     Molecular Weight: 126.5 ± 1.0
#   Cluster 170 (n=8):
#     LogP: -0.58 ± 0.96
#     TPSA: 59.11 ± 10.55
#     Molecular Weight: 124.1 ± 5.8
#   Cluster 171 (n=8):
#     LogP: -0.18 ± 0.77
#     TPSA: 44.82 ± 15.15
#     Molecular Weight: 123.1 ± 5.5
#   Cluster 172 (n=5):
#     LogP: 0.47 ± 0.82
#     TPSA: 34.93 ± 19.18
#     Molecular Weight: 118.2 ± 12.2
#   Cluster 173 (n=13):
#     LogP: 0.61 ± 0.91
#     TPSA: 32.36 ± 16.46
#     Molecular Weight: 124.9 ± 2.5
#   Cluster 174 (n=8):
#     LogP: 0.69 ± 1.24
#     TPSA: 28.29 ± 19.97
#     Molecular Weight: 122.6 ± 4.1
#   Cluster 175 (n=20):
#     LogP: 0.13 ± 1.15
#     TPSA: 36.78 ± 20.44
#     Molecular Weight: 124.0 ± 6.4
#   Cluster 176 (n=6):
#     LogP: 0.27 ± 0.86
#     TPSA: 34.18 ± 12.73
#     Molecular Weight: 124.1 ± 5.5
#   Cluster 177 (n=12):
#     LogP: 0.58 ± 0.78
#     TPSA: 27.37 ± 13.71
#     Molecular Weight: 116.1 ± 10.2
#   Cluster 178 (n=10):
#     LogP: 0.31 ± 0.91
#     TPSA: 37.67 ± 21.02
#     Molecular Weight: 121.6 ± 14.8
#   Cluster 179 (n=27):
#     LogP: 0.25 ± 0.99
#     TPSA: 37.18 ± 23.45
#     Molecular Weight: 122.6 ± 7.4
#   Cluster 180 (n=9):
#     LogP: 0.29 ± 0.86
#     TPSA: 43.79 ± 26.51
#     Molecular Weight: 121.0 ± 9.2
#   Cluster 181 (n=5):
#     LogP: 0.05 ± 0.97
#     TPSA: 43.03 ± 20.85
#     Molecular Weight: 119.5 ± 10.3
#   Cluster 182 (n=10):
#     LogP: 0.19 ± 1.23
#     TPSA: 35.11 ± 22.74
#     Molecular Weight: 122.3 ± 6.7
#   Cluster 183 (n=10):
#     LogP: 0.10 ± 1.03
#     TPSA: 36.48 ± 22.51
#     Molecular Weight: 124.0 ± 6.5
#   Cluster 184 (n=13):
#     LogP: 0.52 ± 1.11
#     TPSA: 38.01 ± 24.61
#     Molecular Weight: 121.5 ± 7.3
#   Cluster 185 (n=6):
#     LogP: 0.46 ± 1.05
#     TPSA: 35.91 ± 22.88
#     Molecular Weight: 124.5 ± 1.6
#   Cluster 186 (n=15):
#     LogP: 0.41 ± 0.79
#     TPSA: 31.36 ± 14.70
#     Molecular Weight: 121.0 ± 6.6
#   Cluster 187 (n=15):
#     LogP: 0.51 ± 0.85
#     TPSA: 38.68 ± 12.37
#     Molecular Weight: 125.6 ± 2.7
#   Cluster 188 (n=8):
#     LogP: 0.07 ± 1.52
#     TPSA: 35.55 ± 18.57
#     Molecular Weight: 124.8 ± 2.3
#   Cluster 189 (n=10):
#     LogP: -0.12 ± 1.31
#     TPSA: 47.57 ± 27.49
#     Molecular Weight: 122.1 ± 6.6
#   Cluster 190 (n=8):
#     LogP: -0.00 ± 1.01
#     TPSA: 42.28 ± 16.93
#     Molecular Weight: 120.0 ± 9.8
#   Cluster 191 (n=13):
#     LogP: 0.15 ± 1.15
#     TPSA: 30.19 ± 22.44
#     Molecular Weight: 122.3 ± 6.9
#   Cluster 192 (n=9):
#     LogP: 0.00 ± 1.42
#     TPSA: 30.52 ± 22.56
#     Molecular Weight: 119.8 ± 7.7
#   Cluster 193 (n=6):
#     LogP: 0.31 ± 0.71
#     TPSA: 35.39 ± 22.23
#     Molecular Weight: 123.0 ± 6.9
#   Cluster 194 (n=14):
#     LogP: 0.74 ± 1.02
#     TPSA: 28.18 ± 19.83
#     Molecular Weight: 124.4 ± 4.4
#   Cluster 195 (n=8):
#     LogP: -0.16 ± 0.98
#     TPSA: 34.90 ± 23.87
#     Molecular Weight: 117.5 ± 12.4
#   Cluster 196 (n=12):
#     LogP: 0.09 ± 0.44
#     TPSA: 42.68 ± 21.30
#     Molecular Weight: 122.3 ± 5.4
#   Cluster 197 (n=7):
#     LogP: 0.19 ± 1.10
#     TPSA: 35.61 ± 25.79
#     Molecular Weight: 125.0 ± 2.5
#   Cluster 198 (n=7):
#     LogP: 0.33 ± 0.97
#     TPSA: 30.57 ± 24.63
#     Molecular Weight: 120.6 ± 6.8
#   Cluster 199 (n=5):
#     LogP: 0.95 ± 1.16
#     TPSA: 24.33 ± 11.92
#     Molecular Weight: 123.4 ± 6.0
#   Cluster 200 (n=9):
#     LogP: 0.58 ± 0.77
#     TPSA: 32.13 ± 12.30
#     Molecular Weight: 120.4 ± 13.9
#   Cluster 201 (n=14):
#     LogP: 0.28 ± 0.82
#     TPSA: 36.59 ± 23.42
#     Molecular Weight: 119.2 ± 8.1
#   Cluster 202 (n=17):
#     LogP: 0.04 ± 0.98
#     TPSA: 42.19 ± 21.14
#     Molecular Weight: 120.8 ± 8.4
#   Cluster 203 (n=10):
#     LogP: 0.21 ± 1.59
#     TPSA: 37.98 ± 19.44
#     Molecular Weight: 124.8 ± 4.8
#   Cluster 204 (n=7):
#     LogP: -0.10 ± 1.03
#     TPSA: 36.56 ± 19.51
#     Molecular Weight: 123.6 ± 4.4
#   Cluster 205 (n=6):
#     LogP: 0.29 ± 0.52
#     TPSA: 37.06 ± 15.47
#     Molecular Weight: 121.6 ± 3.8
#   Cluster 206 (n=5):
#     LogP: -0.32 ± 0.76
#     TPSA: 56.36 ± 19.71
#     Molecular Weight: 122.9 ± 5.8
#   Cluster 207 (n=18):
#     LogP: 0.33 ± 0.90
#     TPSA: 39.12 ± 20.81
#     Molecular Weight: 125.0 ± 4.5
#   Cluster 208 (n=7):
#     LogP: -0.23 ± 1.83
#     TPSA: 33.06 ± 24.94
#     Molecular Weight: 120.3 ± 7.3
#   Cluster 209 (n=80):
#     LogP: 0.40 ± 0.92
#     TPSA: 36.11 ± 19.86
#     Molecular Weight: 121.6 ± 7.9
#   Cluster 210 (n=8):
#     LogP: 0.45 ± 1.41
#     TPSA: 38.94 ± 31.72
#     Molecular Weight: 123.6 ± 4.8
#   Cluster 211 (n=51):
#     LogP: 0.17 ± 0.86
#     TPSA: 38.42 ± 18.82
#     Molecular Weight: 120.1 ± 10.6
#   Cluster 212 (n=6):
#     LogP: 0.13 ± 1.40
#     TPSA: 32.18 ± 22.14
#     Molecular Weight: 121.6 ± 8.6
#   Cluster 213 (n=15):
#     LogP: -0.33 ± 1.24
#     TPSA: 36.88 ± 16.93
#     Molecular Weight: 126.4 ± 2.2
#   Cluster 214 (n=8):
#     LogP: 0.36 ± 0.83
#     TPSA: 42.00 ± 21.99
#     Molecular Weight: 124.5 ± 1.8
#   Cluster 215 (n=6):
#     LogP: 0.50 ± 0.97
#     TPSA: 29.11 ± 13.37
#     Molecular Weight: 125.0 ± 3.4
#   Cluster 216 (n=13):
#     LogP: -0.35 ± 1.35
#     TPSA: 39.44 ± 24.39
#     Molecular Weight: 119.9 ± 8.6
#   Cluster 217 (n=7):
#     LogP: -0.15 ± 0.84
#     TPSA: 43.59 ± 25.28
#     Molecular Weight: 118.4 ± 11.2
#   Cluster 218 (n=5):
#     LogP: -0.62 ± 1.10
#     TPSA: 50.15 ± 19.27
#     Molecular Weight: 124.3 ± 2.2
#   Cluster 219 (n=10):
#     LogP: 0.70 ± 1.19
#     TPSA: 28.77 ± 19.39
#     Molecular Weight: 124.4 ± 4.9
#   Cluster 220 (n=17):
#     LogP: 0.40 ± 1.34
#     TPSA: 29.32 ± 20.65
#     Molecular Weight: 121.2 ± 7.3
#   Cluster 221 (n=14):
#     LogP: -0.10 ± 0.53
#     TPSA: 41.01 ± 16.89
#     Molecular Weight: 120.9 ± 8.0
#   Cluster 222 (n=7):
#     LogP: 0.72 ± 0.67
#     TPSA: 37.14 ± 19.86
#     Molecular Weight: 121.7 ± 7.8
#   Cluster 223 (n=16):
#     LogP: 0.46 ± 0.98
#     TPSA: 36.13 ± 19.14
#     Molecular Weight: 124.3 ± 6.5
#   Cluster 224 (n=6):
#     LogP: 0.55 ± 1.15
#     TPSA: 31.57 ± 20.80
#     Molecular Weight: 121.8 ± 5.9
#   Cluster 225 (n=17):
#     LogP: 0.29 ± 1.21
#     TPSA: 34.15 ± 24.90
#     Molecular Weight: 120.7 ± 9.4
#   Cluster 226 (n=9):
#     LogP: 0.51 ± 0.82
#     TPSA: 30.45 ± 21.63
#     Molecular Weight: 122.8 ± 6.8
#   Cluster 227 (n=6):
#     LogP: 0.45 ± 0.88
#     TPSA: 35.95 ± 14.51
#     Molecular Weight: 123.3 ± 7.1
#   Cluster 228 (n=13):
#     LogP: 0.21 ± 0.76
#     TPSA: 33.82 ± 10.35
#     Molecular Weight: 122.0 ± 5.3
#   Cluster 229 (n=11):
#     LogP: -0.37 ± 1.44
#     TPSA: 39.70 ± 24.26
#     Molecular Weight: 123.2 ± 3.8
#   Cluster 230 (n=8):
#     LogP: -0.25 ± 1.07
#     TPSA: 42.76 ± 27.55
#     Molecular Weight: 117.6 ± 9.7
#   Cluster 231 (n=12):
#     LogP: 0.27 ± 0.84
#     TPSA: 37.44 ± 25.31
#     Molecular Weight: 123.6 ± 5.9
#   Cluster 232 (n=13):
#     LogP: 0.42 ± 0.55
#     TPSA: 35.87 ± 16.50
#     Molecular Weight: 123.6 ± 4.1
#   Cluster 233 (n=37):
#     LogP: 0.26 ± 0.89
#     TPSA: 41.93 ± 21.18
#     Molecular Weight: 123.4 ± 8.2
#   Cluster 234 (n=9):
#     LogP: -0.17 ± 1.54
#     TPSA: 44.82 ± 18.35
#     Molecular Weight: 124.0 ± 6.5
#   Cluster 235 (n=7):
#     LogP: 0.46 ± 1.05
#     TPSA: 32.46 ± 23.36
#     Molecular Weight: 120.2 ± 6.4
#   Cluster 236 (n=6):
#     LogP: 0.62 ± 0.63
#     TPSA: 33.48 ± 14.92
#     Molecular Weight: 119.8 ± 11.2
#   Cluster 237 (n=9):
#     LogP: 0.00 ± 0.91
#     TPSA: 42.85 ± 15.59
#     Molecular Weight: 119.1 ± 5.4
#   Cluster 238 (n=6):
#     LogP: -0.15 ± 0.75
#     TPSA: 39.57 ± 22.48
#     Molecular Weight: 114.5 ± 14.7
#   Cluster 239 (n=12):
#     LogP: 0.48 ± 1.19
#     TPSA: 33.45 ± 18.60
#     Molecular Weight: 121.3 ± 8.7
#   Cluster 240 (n=9):
#     LogP: 0.25 ± 0.44
#     TPSA: 27.03 ± 16.51
#     Molecular Weight: 119.4 ± 10.9
#   Cluster 241 (n=7):
#     LogP: 0.36 ± 1.28
#     TPSA: 39.34 ± 19.66
#     Molecular Weight: 122.9 ± 7.1
#   Cluster 242 (n=7):
#     LogP: 0.60 ± 0.74
#     TPSA: 31.92 ± 11.12
#     Molecular Weight: 124.7 ± 2.0
#   Cluster 243 (n=10):
#     LogP: 0.25 ± 0.63
#     TPSA: 41.42 ± 23.55
#     Molecular Weight: 122.0 ± 6.8
#   Cluster 244 (n=11):
#     LogP: -0.01 ± 1.42
#     TPSA: 42.87 ± 29.17
#     Molecular Weight: 119.1 ± 9.8
#   Cluster 245 (n=5):
#     LogP: 1.16 ± 0.78
#     TPSA: 35.63 ± 21.13
#     Molecular Weight: 122.2 ± 7.6
#   Cluster 246 (n=6):
#     LogP: -0.19 ± 0.90
#     TPSA: 46.32 ± 20.49
#     Molecular Weight: 120.1 ± 12.9
#   Cluster 247 (n=11):
#     LogP: 0.56 ± 1.17
#     TPSA: 31.82 ± 20.69
#     Molecular Weight: 121.7 ± 7.9
#   Cluster 248 (n=8):
#     LogP: 0.32 ± 0.83
#     TPSA: 27.88 ± 12.34
#     Molecular Weight: 124.6 ± 2.6
#   Cluster 249 (n=6):
#     LogP: 1.11 ± 1.21
#     TPSA: 18.89 ± 13.18
#     Molecular Weight: 121.0 ± 6.6
#   Cluster 250 (n=12):
#     LogP: 0.30 ± 1.03
#     TPSA: 44.22 ± 21.03
#     Molecular Weight: 125.4 ± 3.9
#   Cluster 251 (n=10):
#     LogP: 0.51 ± 1.62
#     TPSA: 31.54 ± 26.09
#     Molecular Weight: 123.8 ± 7.7
#   Cluster 252 (n=9):
#     LogP: 0.49 ± 1.09
#     TPSA: 35.09 ± 21.46
#     Molecular Weight: 125.9 ± 2.8
#   Cluster 253 (n=9):
#     LogP: 0.41 ± 0.42
#     TPSA: 36.36 ± 13.03
#     Molecular Weight: 123.7 ± 6.3
#   Cluster 254 (n=9):
#     LogP: -0.71 ± 1.34
#     TPSA: 49.89 ± 22.95
#     Molecular Weight: 124.4 ± 6.6
#   Cluster 255 (n=8):
#     LogP: 0.64 ± 1.21
#     TPSA: 23.22 ± 18.40
#     Molecular Weight: 120.0 ± 6.8
#   Cluster 256 (n=16):
#     LogP: 0.77 ± 0.88
#     TPSA: 34.23 ± 19.26
#     Molecular Weight: 123.4 ± 4.5
#   Cluster 257 (n=6):
#     LogP: 0.22 ± 0.76
#     TPSA: 26.75 ± 10.81
#     Molecular Weight: 123.7 ± 5.9
#   Cluster 258 (n=8):
#     LogP: 0.08 ± 0.77
#     TPSA: 44.93 ± 19.37
#     Molecular Weight: 124.0 ± 5.1
#   Cluster 259 (n=6):
#     LogP: 0.60 ± 1.75
#     TPSA: 33.59 ± 26.14
#     Molecular Weight: 126.0 ± 3.7
#   Cluster 260 (n=7):
#     LogP: 0.08 ± 0.87
#     TPSA: 43.59 ± 25.50
#     Molecular Weight: 123.9 ± 5.8
#   Cluster 261 (n=16):
#     LogP: 0.19 ± 0.85
#     TPSA: 40.75 ± 19.73
#     Molecular Weight: 121.8 ± 6.6
#   Cluster 262 (n=19):
#     LogP: 0.23 ± 1.09
#     TPSA: 33.31 ± 20.30
#     Molecular Weight: 124.2 ± 6.6
#   Cluster 263 (n=6):
#     LogP: 0.15 ± 1.52
#     TPSA: 38.91 ± 26.87
#     Molecular Weight: 125.8 ± 2.9
#   Cluster 264 (n=8):
#     LogP: 0.83 ± 0.50
#     TPSA: 30.61 ± 26.16
#     Molecular Weight: 118.0 ± 10.0
#   Cluster 265 (n=11):
#     LogP: 0.42 ± 0.97
#     TPSA: 42.16 ± 24.11
#     Molecular Weight: 123.3 ± 3.2
#   Cluster 266 (n=11):
#     LogP: -0.06 ± 0.91
#     TPSA: 45.19 ± 17.78
#     Molecular Weight: 123.9 ± 6.1
#   Cluster 267 (n=12):
#     LogP: 0.40 ± 1.10
#     TPSA: 34.61 ± 18.64
#     Molecular Weight: 124.5 ± 5.7
#   Cluster 268 (n=10):
#     LogP: -0.10 ± 0.87
#     TPSA: 48.09 ± 18.33
#     Molecular Weight: 124.7 ± 7.5
#   Cluster 269 (n=6):
#     LogP: 0.18 ± 0.96
#     TPSA: 44.33 ± 25.09
#     Molecular Weight: 125.3 ± 1.9
#   Cluster 270 (n=12):
#     LogP: 0.40 ± 0.76
#     TPSA: 29.35 ± 11.86
#     Molecular Weight: 123.9 ± 5.6
#   Cluster 271 (n=9):
#     LogP: -0.03 ± 1.21
#     TPSA: 38.94 ± 15.60
#     Molecular Weight: 124.1 ± 8.7
#   Cluster 272 (n=10):
#     LogP: 0.59 ± 0.95
#     TPSA: 29.89 ± 15.71
#     Molecular Weight: 123.0 ± 5.0
#   Cluster 273 (n=17):
#     LogP: 0.16 ± 1.33
#     TPSA: 38.78 ± 20.41
#     Molecular Weight: 123.1 ± 9.2
#   Cluster 274 (n=19):
#     LogP: 0.37 ± 0.60
#     TPSA: 37.98 ± 17.12
#     Molecular Weight: 123.9 ± 4.9
#   Cluster 275 (n=20):
#     LogP: 0.34 ± 0.75
#     TPSA: 35.79 ± 17.68
#     Molecular Weight: 121.5 ± 7.4
#   Cluster 276 (n=36):
#     LogP: 0.25 ± 1.08
#     TPSA: 40.48 ± 24.28
#     Molecular Weight: 123.9 ± 5.2
#   Cluster 277 (n=7):
#     LogP: 0.75 ± 0.81
#     TPSA: 28.54 ± 14.79
#     Molecular Weight: 124.6 ± 6.4
#   Cluster 278 (n=6):
#     LogP: 0.77 ± 0.32
#     TPSA: 26.58 ± 20.85
#     Molecular Weight: 119.2 ± 5.8
#   Cluster 279 (n=8):
#     LogP: 0.44 ± 0.84
#     TPSA: 34.06 ± 21.29
#     Molecular Weight: 123.5 ± 6.8
#   Cluster 280 (n=9):
#     LogP: 0.13 ± 1.03
#     TPSA: 35.05 ± 8.71
#     Molecular Weight: 123.0 ± 3.9
#   Cluster 281 (n=13):
#     LogP: 0.35 ± 1.05
#     TPSA: 35.91 ± 20.20
#     Molecular Weight: 123.7 ± 6.1
#   Cluster 282 (n=26):
#     LogP: 0.40 ± 1.21
#     TPSA: 38.21 ± 22.21
#     Molecular Weight: 124.2 ± 6.1
#   Cluster 283 (n=8):
#     LogP: 0.00 ± 0.66
#     TPSA: 40.69 ± 30.38
#     Molecular Weight: 123.8 ± 7.2
#   Cluster 284 (n=11):
#     LogP: 0.55 ± 1.10
#     TPSA: 30.51 ± 23.30
#     Molecular Weight: 125.0 ± 2.5
#   Cluster 285 (n=16):
#     LogP: 0.42 ± 1.07
#     TPSA: 32.43 ± 19.07
#     Molecular Weight: 120.9 ± 10.4
#   Cluster 286 (n=16):
#     LogP: 0.15 ± 0.96
#     TPSA: 37.58 ± 24.19
#     Molecular Weight: 121.5 ± 9.4
#   Cluster 287 (n=12):
#     LogP: 1.04 ± 1.07
#     TPSA: 31.00 ± 27.09
#     Molecular Weight: 121.1 ± 6.9
#   Cluster 288 (n=15):
#     LogP: -0.04 ± 0.96
#     TPSA: 47.58 ± 23.48
#     Molecular Weight: 126.1 ± 2.5
#   Cluster 289 (n=10):
#     LogP: 0.27 ± 1.00
#     TPSA: 39.48 ± 18.69
#     Molecular Weight: 122.4 ± 8.2
#   Cluster 290 (n=6):
#     LogP: 0.25 ± 1.12
#     TPSA: 40.19 ± 22.67
#     Molecular Weight: 123.5 ± 7.4
#   Cluster 291 (n=7):
#     LogP: 0.41 ± 1.14
#     TPSA: 32.85 ± 16.52
#     Molecular Weight: 121.1 ± 7.1
#   Cluster 292 (n=20):
#     LogP: 0.25 ± 1.14
#     TPSA: 44.81 ± 25.27
#     Molecular Weight: 123.2 ± 6.8
#   Cluster 293 (n=150):
#     LogP: 0.47 ± 1.12
#     TPSA: 32.62 ± 20.01
#     Molecular Weight: 122.1 ± 7.8
#   Cluster 294 (n=9):
#     LogP: -0.19 ± 1.00
#     TPSA: 43.55 ± 20.58
#     Molecular Weight: 122.6 ± 8.5
#   Cluster 295 (n=32):
#     LogP: 0.26 ± 1.01
#     TPSA: 38.50 ± 18.44
#     Molecular Weight: 122.4 ± 6.8
#   Cluster 296 (n=15):
#     LogP: 0.35 ± 0.76
#     TPSA: 37.01 ± 22.90
#     Molecular Weight: 120.5 ± 8.2
#   Cluster 297 (n=7):
#     LogP: 0.16 ± 0.51
#     TPSA: 45.14 ± 8.92
#     Molecular Weight: 124.3 ± 6.2
#   Cluster 298 (n=11):
#     LogP: 0.05 ± 1.16
#     TPSA: 43.01 ± 27.09
#     Molecular Weight: 124.1 ± 6.9
#   Cluster 299 (n=11):
#     LogP: 0.67 ± 0.97
#     TPSA: 25.72 ± 18.28
#     Molecular Weight: 121.5 ± 7.1
#   Cluster 300 (n=8):
#     LogP: 0.21 ± 1.21
#     TPSA: 39.98 ± 23.33
#     Molecular Weight: 123.0 ± 5.2
#   Cluster 301 (n=12):
#     LogP: 0.40 ± 1.15
#     TPSA: 34.27 ± 24.65
#     Molecular Weight: 124.3 ± 4.4
#   Cluster 302 (n=13):
#     LogP: 0.67 ± 0.92
#     TPSA: 35.09 ± 20.98
#     Molecular Weight: 117.8 ± 17.9
#   Cluster 303 (n=19):
#     LogP: 0.27 ± 0.67
#     TPSA: 35.19 ± 17.13
#     Molecular Weight: 122.3 ± 7.7
#   Cluster 304 (n=15):
#     LogP: 0.46 ± 0.87
#     TPSA: 34.57 ± 16.87
#     Molecular Weight: 122.9 ± 5.2
#   Cluster 305 (n=6):
#     LogP: 0.55 ± 1.38
#     TPSA: 23.75 ± 26.81
#     Molecular Weight: 117.8 ± 13.1
#   Cluster 306 (n=7):
#     LogP: 0.38 ± 0.71
#     TPSA: 37.13 ± 17.43
#     Molecular Weight: 123.0 ± 7.1
#   Cluster 307 (n=33):
#     LogP: 0.53 ± 1.11
#     TPSA: 32.61 ± 19.29
#     Molecular Weight: 123.2 ± 5.3
#   Cluster 308 (n=13):
#     LogP: 0.34 ± 1.17
#     TPSA: 35.40 ± 21.95
#     Molecular Weight: 124.1 ± 6.3
#   Cluster 309 (n=5):
#     LogP: 0.69 ± 0.83
#     TPSA: 34.60 ± 9.66
#     Molecular Weight: 125.4 ± 6.9
#   Cluster 310 (n=6):
#     LogP: 0.45 ± 0.67
#     TPSA: 31.27 ± 15.89
#     Molecular Weight: 122.3 ± 8.9
#   Cluster 311 (n=7):
#     LogP: 0.11 ± 0.88
#     TPSA: 37.26 ± 16.41
#     Molecular Weight: 122.0 ± 11.2
#   Cluster 312 (n=6):
#     LogP: 0.42 ± 0.83
#     TPSA: 29.95 ± 14.27
#     Molecular Weight: 122.1 ± 6.9
#   Cluster 313 (n=13):
#     LogP: 0.17 ± 1.03
#     TPSA: 37.02 ± 19.16
#     Molecular Weight: 126.0 ± 3.6
#   Cluster 314 (n=14):
#     LogP: 0.03 ± 1.66
#     TPSA: 44.45 ± 26.82
#     Molecular Weight: 124.5 ± 4.6
#   Cluster 315 (n=10):
#     LogP: 0.19 ± 1.08
#     TPSA: 36.75 ± 17.67
#     Molecular Weight: 127.7 ± 1.9
#   Cluster 316 (n=10):
#     LogP: -0.04 ± 0.72
#     TPSA: 40.09 ± 22.72
#     Molecular Weight: 120.8 ± 8.9
#   Cluster 317 (n=7):
#     LogP: 0.29 ± 1.11
#     TPSA: 45.21 ± 23.23
#     Molecular Weight: 124.0 ± 4.9
#   Cluster 318 (n=25):
#     LogP: 0.78 ± 0.94
#     TPSA: 28.42 ± 16.00
#     Molecular Weight: 123.7 ± 5.4
#   Cluster 319 (n=14):
#     LogP: 0.40 ± 1.06
#     TPSA: 36.86 ± 23.49
#     Molecular Weight: 123.3 ± 6.7
#   Cluster 320 (n=8):
#     LogP: 0.65 ± 0.81
#     TPSA: 32.41 ± 21.61
#     Molecular Weight: 123.2 ± 5.5
#   Cluster 321 (n=12):
#     LogP: 0.72 ± 0.78
#     TPSA: 26.54 ± 11.07
#     Molecular Weight: 121.5 ± 5.4
#   Cluster 322 (n=24):
#     LogP: 0.34 ± 1.04
#     TPSA: 36.43 ± 24.82
#     Molecular Weight: 120.7 ± 7.3
#   Cluster 323 (n=8):
#     LogP: 0.07 ± 0.70
#     TPSA: 37.88 ± 15.03
#     Molecular Weight: 124.9 ± 2.9
#   Cluster 324 (n=8):
#     LogP: 0.12 ± 1.04
#     TPSA: 30.47 ± 13.87
#     Molecular Weight: 123.9 ± 6.0
#   Cluster 325 (n=9):
#     LogP: 0.35 ± 0.81
#     TPSA: 37.79 ± 18.09
#     Molecular Weight: 119.8 ± 8.1
#   Cluster 326 (n=7):
#     LogP: 1.06 ± 1.35
#     TPSA: 21.80 ± 19.85
#     Molecular Weight: 120.3 ± 10.9
#   Cluster 327 (n=18):
#     LogP: 0.45 ± 1.22
#     TPSA: 37.98 ± 25.24
#     Molecular Weight: 122.6 ± 6.5
#   Cluster 328 (n=15):
#     LogP: 0.21 ± 1.13
#     TPSA: 42.47 ± 18.93
#     Molecular Weight: 124.5 ± 4.6
#   Cluster 329 (n=6):
#     LogP: -0.26 ± 0.98
#     TPSA: 34.33 ± 17.88
#     Molecular Weight: 125.3 ± 1.7
#   Cluster 330 (n=9):
#     LogP: 0.01 ± 1.53
#     TPSA: 36.09 ± 21.08
#     Molecular Weight: 121.8 ± 7.0
#   Cluster 331 (n=12):
#     LogP: 0.89 ± 0.86
#     TPSA: 23.42 ± 17.81
#     Molecular Weight: 120.3 ± 6.3
#   Cluster 332 (n=21):
#     LogP: 0.54 ± 0.81
#     TPSA: 33.44 ± 19.53
#     Molecular Weight: 122.7 ± 7.5
#   Cluster 333 (n=6):
#     LogP: 0.49 ± 1.14
#     TPSA: 41.00 ± 20.57
#     Molecular Weight: 124.6 ± 5.4
#   Cluster 334 (n=10):
#     LogP: 0.27 ± 1.06
#     TPSA: 34.53 ± 16.29
#     Molecular Weight: 124.1 ± 6.6
#   Cluster 335 (n=11):
#     LogP: 0.41 ± 1.33
#     TPSA: 41.45 ± 21.28
#     Molecular Weight: 120.5 ± 6.8
#   Cluster 336 (n=12):
#     LogP: 0.61 ± 1.15
#     TPSA: 42.00 ± 24.84
#     Molecular Weight: 121.5 ± 8.7
#   Cluster 337 (n=10):
#     LogP: 0.00 ± 0.95
#     TPSA: 46.02 ± 24.56
#     Molecular Weight: 123.8 ± 7.5
#   Cluster 338 (n=10):
#     LogP: 0.39 ± 0.64
#     TPSA: 34.82 ± 11.65
#     Molecular Weight: 122.1 ± 6.7
#   Cluster 339 (n=29):
#     LogP: 0.45 ± 0.87
#     TPSA: 33.60 ± 18.08
#     Molecular Weight: 125.2 ± 3.8
#   Cluster 340 (n=13):
#     LogP: -0.17 ± 1.56
#     TPSA: 41.84 ± 28.45
#     Molecular Weight: 121.5 ± 10.8
#   Cluster 341 (n=14):
#     LogP: -0.39 ± 1.43
#     TPSA: 45.82 ± 19.42
#     Molecular Weight: 125.0 ± 4.3
#   Cluster 342 (n=9):
#     LogP: 0.35 ± 1.00
#     TPSA: 37.97 ± 18.60
#     Molecular Weight: 121.6 ± 10.4
#   Cluster 343 (n=21):
#     LogP: 0.62 ± 1.04
#     TPSA: 26.34 ± 16.14
#     Molecular Weight: 120.1 ± 10.4
#   Cluster 344 (n=9):
#     LogP: -0.09 ± 0.56
#     TPSA: 37.25 ± 11.57
#     Molecular Weight: 125.1 ± 2.3
#   Cluster 345 (n=16):
#     LogP: 0.10 ± 0.94
#     TPSA: 38.61 ± 17.81
#     Molecular Weight: 125.4 ± 4.9
#   Cluster 346 (n=9):
#     LogP: -0.18 ± 1.52
#     TPSA: 41.05 ± 19.27
#     Molecular Weight: 124.4 ± 5.1
#   Cluster 347 (n=9):
#     LogP: 0.73 ± 0.83
#     TPSA: 43.17 ± 17.43
#     Molecular Weight: 121.0 ± 6.9
#   Cluster 348 (n=7):
#     LogP: 0.09 ± 0.71
#     TPSA: 32.30 ± 19.86
#     Molecular Weight: 121.7 ± 7.4
#   Cluster 349 (n=9):
#     LogP: -0.02 ± 0.85
#     TPSA: 42.21 ± 28.04
#     Molecular Weight: 121.8 ± 5.6
#   Cluster 350 (n=11):
#     LogP: 0.45 ± 0.56
#     TPSA: 35.80 ± 18.36
#     Molecular Weight: 122.3 ± 7.2
#   Cluster 351 (n=8):
#     LogP: 0.12 ± 0.43
#     TPSA: 40.48 ± 11.48
#     Molecular Weight: 124.5 ± 6.1
#   Cluster 352 (n=9):
#     LogP: 0.38 ± 0.66
#     TPSA: 32.18 ± 15.91
#     Molecular Weight: 120.6 ± 7.8
#   Cluster 353 (n=7):
#     LogP: 0.58 ± 0.77
#     TPSA: 31.68 ± 15.36
#     Molecular Weight: 123.9 ± 5.6
#   Cluster 354 (n=14):
#     LogP: 0.31 ± 0.63
#     TPSA: 33.24 ± 13.58
#     Molecular Weight: 123.6 ± 6.9
#   Cluster 355 (n=13):
#     LogP: 0.13 ± 0.71
#     TPSA: 34.26 ± 15.72
#     Molecular Weight: 122.6 ± 12.7
#   Cluster 356 (n=8):
#     LogP: 0.47 ± 0.81
#     TPSA: 39.42 ± 17.43
#     Molecular Weight: 124.8 ± 4.6
#   Cluster 357 (n=7):
#     LogP: 1.09 ± 0.87
#     TPSA: 23.70 ± 22.92
#     Molecular Weight: 123.5 ± 6.4
#   Cluster 358 (n=41):
#     LogP: 0.74 ± 1.15
#     TPSA: 29.25 ± 21.07
#     Molecular Weight: 123.1 ± 7.2
#   Cluster 359 (n=17):
#     LogP: 0.44 ± 1.05
#     TPSA: 43.12 ± 28.60
#     Molecular Weight: 122.8 ± 4.8
#   Cluster 360 (n=11):
#     LogP: 0.21 ± 0.78
#     TPSA: 49.78 ± 23.74
#     Molecular Weight: 124.8 ± 6.3
#   Cluster 361 (n=9):
#     LogP: 0.93 ± 1.13
#     TPSA: 23.86 ± 14.91
#     Molecular Weight: 117.8 ± 14.9
#   Cluster 362 (n=6):
#     LogP: 0.04 ± 0.80
#     TPSA: 35.15 ± 13.92
#     Molecular Weight: 124.3 ± 6.7
#   Cluster 363 (n=8):
#     LogP: -0.09 ± 1.83
#     TPSA: 35.32 ± 28.22
#     Molecular Weight: 119.2 ± 14.7
#   Cluster 364 (n=6):
#     LogP: 0.81 ± 0.74
#     TPSA: 26.62 ± 13.27
#     Molecular Weight: 121.0 ± 3.5
#   Cluster 365 (n=13):
#     LogP: 0.48 ± 0.86
#     TPSA: 34.59 ± 19.26
#     Molecular Weight: 120.0 ± 11.0
#   Cluster 366 (n=6):
#     LogP: 0.98 ± 1.07
#     TPSA: 40.22 ± 33.33
#     Molecular Weight: 125.7 ± 2.5
#   Cluster 367 (n=15):
#     LogP: 0.25 ± 1.00
#     TPSA: 37.15 ± 21.10
#     Molecular Weight: 121.7 ± 7.7
#   Cluster 368 (n=8):
#     LogP: 0.12 ± 0.85
#     TPSA: 42.82 ± 20.87
#     Molecular Weight: 120.6 ± 7.8
#   Cluster 369 (n=7):
#     LogP: 0.53 ± 0.88
#     TPSA: 34.10 ± 28.12
#     Molecular Weight: 119.0 ± 8.8
#   Cluster 370 (n=9):
#     LogP: 0.01 ± 0.74
#     TPSA: 34.57 ± 20.08
#     Molecular Weight: 121.0 ± 8.4
#   Cluster 371 (n=7):
#     LogP: -0.66 ± 1.09
#     TPSA: 57.45 ± 31.92
#     Molecular Weight: 122.1 ± 11.8
#   Cluster 372 (n=8):
#     LogP: -0.27 ± 0.67
#     TPSA: 58.18 ± 17.54
#     Molecular Weight: 123.7 ± 5.5
#   Cluster 373 (n=10):
#     LogP: 1.00 ± 0.63
#     TPSA: 30.27 ± 22.62
#     Molecular Weight: 121.5 ± 9.7
#   Cluster 374 (n=19):
#     LogP: 0.29 ± 0.73
#     TPSA: 37.67 ± 22.46
#     Molecular Weight: 123.5 ± 5.7
#   Cluster 375 (n=6):
#     LogP: -1.05 ± 0.70
#     TPSA: 57.81 ± 20.15
#     Molecular Weight: 127.0 ± 2.9
#   Cluster 376 (n=19):
#     LogP: -0.05 ± 0.72
#     TPSA: 37.81 ± 18.99
#     Molecular Weight: 120.9 ± 9.5
#   Cluster 377 (n=10):
#     LogP: 0.53 ± 1.18
#     TPSA: 40.64 ± 36.26
#     Molecular Weight: 125.7 ± 2.5
#   Cluster 378 (n=8):
#     LogP: 0.52 ± 0.68
#     TPSA: 28.12 ± 17.93
#     Molecular Weight: 119.6 ± 6.2
#   Cluster 379 (n=12):
#     LogP: 0.45 ± 0.88
#     TPSA: 42.25 ± 18.30
#     Molecular Weight: 116.6 ± 14.1
#   Cluster 380 (n=8):
#     LogP: 0.62 ± 0.75
#     TPSA: 19.52 ± 10.65
#     Molecular Weight: 119.4 ± 4.5
#   Cluster 381 (n=16):
#     LogP: 0.27 ± 0.95
#     TPSA: 39.93 ± 24.35
#     Molecular Weight: 124.0 ± 7.9
#   Cluster 382 (n=26):
#     LogP: 0.32 ± 0.82
#     TPSA: 34.35 ± 19.61
#     Molecular Weight: 121.5 ± 7.7
#   Cluster 383 (n=14):
#     LogP: 0.40 ± 1.10
#     TPSA: 35.66 ± 19.80
#     Molecular Weight: 122.8 ± 5.2
#   Cluster 384 (n=12):
#     LogP: 0.13 ± 0.85
#     TPSA: 35.64 ± 25.42
#     Molecular Weight: 119.6 ± 13.5
#   Cluster 385 (n=15):
#     LogP: 0.42 ± 1.07
#     TPSA: 38.38 ± 25.73
#     Molecular Weight: 120.4 ± 8.3
#   Cluster 386 (n=30):
#     LogP: 0.48 ± 0.86
#     TPSA: 36.40 ± 19.15
#     Molecular Weight: 124.9 ± 4.1
#   Cluster 387 (n=12):
#     LogP: 0.48 ± 0.85
#     TPSA: 40.08 ± 24.56
#     Molecular Weight: 123.1 ± 6.3
#   Cluster 388 (n=14):
#     LogP: 0.53 ± 1.03
#     TPSA: 38.25 ± 26.67
#     Molecular Weight: 125.0 ± 2.6
#   Cluster 389 (n=11):
#     LogP: 0.03 ± 1.16
#     TPSA: 41.36 ± 27.76
#     Molecular Weight: 118.2 ± 11.3
#   Cluster 390 (n=6):
#     LogP: 0.60 ± 0.97
#     TPSA: 23.36 ± 20.78
#     Molecular Weight: 122.5 ± 6.3
#   Cluster 391 (n=5):
#     LogP: 0.25 ± 0.95
#     TPSA: 36.04 ± 19.61
#     Molecular Weight: 119.7 ± 7.9
#   Cluster 392 (n=10):
#     LogP: 0.15 ± 0.82
#     TPSA: 49.30 ± 22.68
#     Molecular Weight: 122.5 ± 5.0
#   Cluster 393 (n=12):
#     LogP: 0.16 ± 0.87
#     TPSA: 36.76 ± 18.38
#     Molecular Weight: 123.2 ± 8.2
#   Cluster 394 (n=5):
#     LogP: 0.41 ± 0.55
#     TPSA: 26.06 ± 15.46
#     Molecular Weight: 123.4 ± 5.9
#   Cluster 395 (n=6):
#     LogP: 0.58 ± 0.79
#     TPSA: 31.10 ± 14.90
#     Molecular Weight: 123.2 ± 6.7
#   Cluster 396 (n=11):
#     LogP: 0.24 ± 1.00
#     TPSA: 32.04 ± 20.82
#     Molecular Weight: 121.7 ± 4.5
#   Cluster 397 (n=6):
#     LogP: 0.00 ± 1.14
#     TPSA: 54.78 ± 20.33
#     Molecular Weight: 121.3 ± 7.8
#   Cluster 398 (n=19):
#     LogP: -0.21 ± 0.80
#     TPSA: 40.25 ± 18.88
#     Molecular Weight: 124.9 ± 2.7
#   Cluster 399 (n=11):
#     LogP: 0.54 ± 0.79
#     TPSA: 42.96 ± 29.31
#     Molecular Weight: 122.8 ± 6.7
#   Cluster 400 (n=13):
#     LogP: 0.42 ± 1.07
#     TPSA: 40.15 ± 25.95
#     Molecular Weight: 122.8 ± 8.9
#   Cluster 401 (n=11):
#     LogP: -0.02 ± 1.11
#     TPSA: 46.85 ± 27.91
#     Molecular Weight: 123.0 ± 5.2
#   Cluster 402 (n=15):
#     LogP: 0.66 ± 1.10
#     TPSA: 30.34 ± 25.46
#     Molecular Weight: 124.0 ± 4.5
#   Cluster 403 (n=10):
#     LogP: 0.36 ± 1.03
#     TPSA: 40.76 ± 26.25
#     Molecular Weight: 120.9 ± 8.2
#   Cluster 404 (n=9):
#     LogP: 0.13 ± 1.28
#     TPSA: 36.74 ± 24.59
#     Molecular Weight: 121.7 ± 7.8
#   Cluster 405 (n=6):
#     LogP: -0.12 ± 0.51
#     TPSA: 45.55 ± 9.90
#     Molecular Weight: 126.8 ± 3.6
#   Cluster 406 (n=8):
#     LogP: 0.05 ± 1.08
#     TPSA: 42.05 ± 27.60
#     Molecular Weight: 125.3 ± 2.2
#   Cluster 407 (n=13):
#     LogP: -0.28 ± 1.17
#     TPSA: 51.62 ± 32.70
#     Molecular Weight: 122.2 ± 7.6
#   Cluster 408 (n=7):
#     LogP: -0.83 ± 2.11
#     TPSA: 45.96 ± 35.05
#     Molecular Weight: 121.0 ± 9.1
#   Cluster 409 (n=6):
#     LogP: 0.20 ± 1.23
#     TPSA: 46.52 ± 24.38
#     Molecular Weight: 124.7 ± 1.6
#   Cluster 410 (n=6):
#     LogP: 0.40 ± 1.19
#     TPSA: 23.26 ± 12.29
#     Molecular Weight: 117.5 ± 10.4
#   Cluster 411 (n=10):
#     LogP: 0.84 ± 1.17
#     TPSA: 31.71 ± 26.62
#     Molecular Weight: 126.0 ± 2.4
#   Cluster 412 (n=15):
#     LogP: 0.08 ± 1.35
#     TPSA: 36.54 ± 26.50
#     Molecular Weight: 121.9 ± 7.6
#   Cluster 413 (n=6):
#     LogP: 0.17 ± 1.09
#     TPSA: 42.17 ± 21.56
#     Molecular Weight: 123.5 ± 6.8
#   Cluster 414 (n=12):
#     LogP: 0.47 ± 0.76
#     TPSA: 38.17 ± 16.46
#     Molecular Weight: 122.0 ± 9.1
#   Cluster 415 (n=6):
#     LogP: 0.11 ± 0.88
#     TPSA: 43.45 ± 21.44
#     Molecular Weight: 117.3 ± 19.3
#   Cluster 416 (n=16):
#     LogP: 0.37 ± 1.08
#     TPSA: 36.65 ± 20.32
#     Molecular Weight: 123.7 ± 6.1
#   Cluster 417 (n=14):
#     LogP: 0.66 ± 1.14
#     TPSA: 37.48 ± 27.63
#     Molecular Weight: 124.4 ± 4.6
#   Cluster 418 (n=9):
#     LogP: 0.11 ± 0.81
#     TPSA: 40.21 ± 24.55
#     Molecular Weight: 121.5 ± 4.8
#   Cluster 419 (n=22):
#     LogP: 0.68 ± 1.13
#     TPSA: 27.31 ± 22.17
#     Molecular Weight: 123.4 ± 5.4
#   Cluster 420 (n=11):
#     LogP: 0.42 ± 1.15
#     TPSA: 35.06 ± 23.95
#     Molecular Weight: 125.0 ± 2.4
#   Cluster 421 (n=6):
#     LogP: 0.87 ± 1.12
#     TPSA: 31.23 ± 23.96
#     Molecular Weight: 126.3 ± 2.6
#   Cluster 422 (n=17):
#     LogP: 0.19 ± 1.14
#     TPSA: 41.91 ± 22.61
#     Molecular Weight: 125.3 ± 4.2
#   Cluster 423 (n=6):
#     LogP: 0.47 ± 0.82
#     TPSA: 24.37 ± 15.39
#     Molecular Weight: 121.0 ± 8.9
#   Cluster 424 (n=9):
#     LogP: -0.09 ± 1.43
#     TPSA: 35.05 ± 15.73
#     Molecular Weight: 120.4 ± 9.6
#   Cluster 425 (n=7):
#     LogP: 0.53 ± 1.10
#     TPSA: 31.60 ± 26.63
#     Molecular Weight: 121.6 ± 4.4
#   Cluster 426 (n=12):
#     LogP: 0.17 ± 1.10
#     TPSA: 42.10 ± 29.80
#     Molecular Weight: 123.0 ± 9.2
#   Cluster 427 (n=8):
#     LogP: -0.00 ± 1.04
#     TPSA: 46.48 ± 23.24
#     Molecular Weight: 126.0 ± 1.9
#   Cluster 428 (n=11):
#     LogP: 0.24 ± 1.11
#     TPSA: 50.03 ± 19.60
#     Molecular Weight: 123.9 ± 6.5
#   Cluster 429 (n=16):
#     LogP: 0.14 ± 1.06
#     TPSA: 35.90 ± 18.72
#     Molecular Weight: 121.8 ± 9.0
#   Cluster 430 (n=7):
#     LogP: 0.67 ± 0.81
#     TPSA: 31.40 ± 21.13
#     Molecular Weight: 123.0 ± 6.4
#   Cluster 431 (n=25):
#     LogP: 0.63 ± 1.23
#     TPSA: 29.48 ± 26.59
#     Molecular Weight: 122.4 ± 9.8
#   Cluster 432 (n=6):
#     LogP: 0.22 ± 0.92
#     TPSA: 21.12 ± 15.23
#     Molecular Weight: 122.0 ± 8.4
#   Cluster 433 (n=8):
#     LogP: 0.23 ± 0.76
#     TPSA: 35.08 ± 19.23
#     Molecular Weight: 123.8 ± 5.8
#   Cluster 434 (n=11):
#     LogP: 0.17 ± 1.03
#     TPSA: 45.69 ± 22.31
#     Molecular Weight: 121.8 ± 6.8
#   Cluster 435 (n=8):
#     LogP: -0.13 ± 1.58
#     TPSA: 49.05 ± 29.53
#     Molecular Weight: 119.8 ± 14.9
#   Cluster 436 (n=6):
#     LogP: 0.53 ± 1.13
#     TPSA: 36.71 ± 24.44
#     Molecular Weight: 128.2 ± 1.9
#   Cluster 437 (n=16):
#     LogP: 0.20 ± 0.78
#     TPSA: 32.41 ± 14.03
#     Molecular Weight: 119.4 ± 14.6
#   Cluster 438 (n=13):
#     LogP: 0.54 ± 0.83
#     TPSA: 35.18 ± 20.66
#     Molecular Weight: 123.8 ± 4.1
#   Cluster 439 (n=12):
#     LogP: 0.19 ± 1.43
#     TPSA: 44.09 ± 24.41
#     Molecular Weight: 121.1 ± 9.2
#   Cluster 440 (n=8):
#     LogP: 0.11 ± 0.32
#     TPSA: 43.13 ± 23.71
#     Molecular Weight: 122.5 ± 10.5
#   Cluster 441 (n=6):
#     LogP: 1.11 ± 1.09
#     TPSA: 33.39 ± 29.67
#     Molecular Weight: 122.5 ± 4.3
#   Cluster 442 (n=22):
#     LogP: 0.52 ± 0.95
#     TPSA: 28.86 ± 15.38
#     Molecular Weight: 122.1 ± 7.1
#   Cluster 443 (n=10):
#     LogP: 0.37 ± 1.21
#     TPSA: 35.56 ± 24.61
#     Molecular Weight: 125.9 ± 1.5
#   Cluster 444 (n=8):
#     LogP: -0.16 ± 0.98
#     TPSA: 45.96 ± 17.08
#     Molecular Weight: 125.9 ± 1.6
#   Cluster 445 (n=12):
#     LogP: 0.18 ± 0.84
#     TPSA: 42.61 ± 25.95
#     Molecular Weight: 125.4 ± 5.5
#   Cluster 446 (n=8):
#     LogP: 0.45 ± 1.15
#     TPSA: 38.69 ± 28.50
#     Molecular Weight: 120.9 ± 17.5
#   Cluster 447 (n=11):
#     LogP: 0.37 ± 0.89
#     TPSA: 31.76 ± 14.11
#     Molecular Weight: 122.1 ± 5.7
#   Cluster 448 (n=21):
#     LogP: 0.41 ± 1.12
#     TPSA: 38.90 ± 23.78
#     Molecular Weight: 124.8 ± 5.0
#   Cluster 449 (n=16):
#     LogP: 0.24 ± 1.06
#     TPSA: 39.44 ± 24.34
#     Molecular Weight: 123.4 ± 8.3
#   Cluster 450 (n=6):
#     LogP: 0.36 ± 0.74
#     TPSA: 33.60 ± 21.52
#     Molecular Weight: 123.5 ± 5.7
#   Cluster 451 (n=9):
#     LogP: 0.42 ± 0.57
#     TPSA: 32.01 ± 17.50
#     Molecular Weight: 123.2 ± 2.9
#   Cluster 452 (n=15):
#     LogP: 0.44 ± 1.12
#     TPSA: 38.09 ± 20.54
#     Molecular Weight: 123.2 ± 5.0
#   Cluster 453 (n=13):
#     LogP: -0.16 ± 0.92
#     TPSA: 37.61 ± 17.14
#     Molecular Weight: 123.4 ± 5.9
#   Cluster 454 (n=10):
#     LogP: 0.34 ± 1.48
#     TPSA: 30.82 ± 16.85
#     Molecular Weight: 125.9 ± 4.1
#   Cluster 455 (n=11):
#     LogP: 0.38 ± 1.01
#     TPSA: 30.16 ± 21.98
#     Molecular Weight: 123.2 ± 4.8
#   Cluster 456 (n=14):
#     LogP: 0.13 ± 1.08
#     TPSA: 38.66 ± 27.77
#     Molecular Weight: 122.4 ± 5.9
#   Cluster 457 (n=14):
#     LogP: 0.04 ± 0.84
#     TPSA: 42.61 ± 20.53
#     Molecular Weight: 121.9 ± 5.9
#   Cluster 458 (n=12):
#     LogP: 0.33 ± 0.88
#     TPSA: 34.25 ± 21.17
#     Molecular Weight: 119.8 ± 9.7
#   Cluster 459 (n=8):
#     LogP: 0.49 ± 0.95
#     TPSA: 37.75 ± 24.68
#     Molecular Weight: 123.4 ± 6.3
#   Cluster 460 (n=32):
#     LogP: 0.24 ± 0.86
#     TPSA: 42.76 ± 25.05
#     Molecular Weight: 121.7 ± 9.4
#   Cluster 461 (n=7):
#     LogP: 0.13 ± 1.09
#     TPSA: 44.80 ± 21.92
#     Molecular Weight: 121.7 ± 10.5
#   Cluster 462 (n=8):
#     LogP: -0.12 ± 0.60
# ...
#     TPSA: 33.71 ± 29.18
#     Molecular Weight: 123.0 ± 4.2
#   Cluster 1086 (n=8):
#     LogP: -0.20 ± 0.94
#     TPSA: 50.14 ± 18.90
#     Molecular Weight: 119.9 ± 9.2
#   Cluster 1087 (n=9):
#     LogP: 0.23 ± 0.95
#     TPSA: 37.69 ± 24.80
#     Molecular Weight: 127.1 ± 4.0
#   Cluster 1088 (n=17):
#     LogP: 0.37 ± 0.99
#     TPSA: 34.96 ± 19.49
#     Molecular Weight: 124.2 ± 5.3
#   Cluster 1089 (n=7):
#     LogP: 0.22 ± 0.71
#     TPSA: 27.08 ± 14.43
#     Molecular Weight: 122.0 ± 8.8
#   Cluster 1090 (n=12):
#     LogP: 0.06 ± 0.96
#     TPSA: 39.76 ± 20.60
#     Molecular Weight: 123.5 ± 5.2
#   Cluster 1091 (n=18):
#     LogP: 0.24 ± 0.70
#     TPSA: 47.83 ± 16.53
#     Molecular Weight: 125.3 ± 2.7
#   Cluster 1092 (n=11):
#     LogP: 0.37 ± 1.22
#     TPSA: 37.09 ± 23.17
#     Molecular Weight: 121.7 ± 7.3
#   Cluster 1093 (n=9):
#     LogP: 0.52 ± 0.77
#     TPSA: 29.73 ± 16.75
#     Molecular Weight: 119.7 ± 10.7
#   Cluster 1094 (n=13):
#     LogP: 0.59 ± 0.95
#     TPSA: 27.80 ± 18.87
#     Molecular Weight: 124.8 ± 2.3
#   Cluster 1095 (n=7):
#     LogP: -0.05 ± 0.58
#     TPSA: 30.95 ± 16.58
#     Molecular Weight: 124.6 ± 6.0
#   Cluster 1096 (n=11):
#     LogP: 0.67 ± 1.21
#     TPSA: 33.70 ± 21.03
#     Molecular Weight: 121.8 ± 5.5
#   Cluster 1097 (n=8):
#     LogP: 0.21 ± 0.97
#     TPSA: 39.31 ± 28.61
#     Molecular Weight: 122.4 ± 10.9
#   Cluster 1098 (n=9):
#     LogP: 0.63 ± 0.83
#     TPSA: 37.41 ± 20.97
#     Molecular Weight: 124.2 ± 5.5
#   Cluster 1099 (n=16):
#     LogP: 0.43 ± 1.15
#     TPSA: 29.49 ± 19.67
#     Molecular Weight: 120.9 ± 8.3
#   Cluster 1100 (n=7):
#     LogP: -0.04 ± 0.71
#     TPSA: 41.19 ± 10.84
#     Molecular Weight: 124.7 ± 6.7
#   Cluster 1101 (n=13):
#     LogP: 0.28 ± 1.21
#     TPSA: 41.21 ± 30.53
#     Molecular Weight: 121.3 ± 7.9
#   Cluster 1102 (n=12):
#     LogP: -0.11 ± 1.19
#     TPSA: 45.81 ± 26.62
#     Molecular Weight: 121.1 ± 7.7
#   Cluster 1103 (n=15):
#     LogP: -0.18 ± 1.53
#     TPSA: 46.43 ± 26.04
#     Molecular Weight: 117.5 ± 15.8
#   Cluster 1104 (n=7):
#     LogP: 0.26 ± 0.86
#     TPSA: 37.77 ± 19.23
#     Molecular Weight: 123.1 ± 5.5
#   Cluster 1105 (n=7):
#     LogP: 0.46 ± 0.88
#     TPSA: 35.41 ± 12.64
#     Molecular Weight: 120.7 ± 11.9
#   Cluster 1106 (n=12):
#     LogP: 0.13 ± 0.61
#     TPSA: 50.91 ± 26.98
#     Molecular Weight: 121.9 ± 8.5
#   Cluster 1107 (n=11):
#     LogP: 0.48 ± 1.08
#     TPSA: 36.85 ± 27.48
#     Molecular Weight: 124.7 ± 5.4
#   Cluster 1108 (n=23):
#     LogP: 0.31 ± 1.10
#     TPSA: 35.12 ± 22.63
#     Molecular Weight: 123.3 ± 5.2
#   Cluster 1109 (n=11):
#     LogP: 0.48 ± 1.26
#     TPSA: 32.76 ± 26.36
#     Molecular Weight: 123.0 ± 6.8
#   Cluster 1110 (n=16):
#     LogP: 0.31 ± 0.60
#     TPSA: 31.26 ± 13.39
#     Molecular Weight: 123.8 ± 4.6
#   Cluster 1111 (n=7):
#     LogP: 0.59 ± 1.26
#     TPSA: 33.96 ± 17.92
#     Molecular Weight: 127.3 ± 3.3
#   Cluster 1112 (n=9):
#     LogP: -0.44 ± 1.73
#     TPSA: 49.26 ± 18.18
#     Molecular Weight: 126.4 ± 5.4
#   Cluster 1113 (n=9):
#     LogP: 0.22 ± 0.99
#     TPSA: 44.94 ± 23.76
#     Molecular Weight: 124.3 ± 7.0
#   Cluster 1114 (n=7):
#     LogP: -0.44 ± 0.98
#     TPSA: 55.81 ± 34.55
#     Molecular Weight: 123.3 ± 6.6
#   Cluster 1115 (n=10):
#     LogP: 0.42 ± 1.05
#     TPSA: 35.45 ± 16.96
#     Molecular Weight: 119.2 ± 6.5
#   Cluster 1116 (n=13):
#     LogP: 1.15 ± 1.11
#     TPSA: 22.68 ± 24.45
#     Molecular Weight: 122.8 ± 5.6
#   Cluster 1117 (n=13):
#     LogP: 0.63 ± 1.00
#     TPSA: 31.85 ± 18.93
#     Molecular Weight: 125.7 ± 3.2
#   Cluster 1118 (n=16):
#     LogP: -0.02 ± 1.31
#     TPSA: 39.03 ± 23.27
#     Molecular Weight: 124.8 ± 4.8
#   Cluster 1119 (n=14):
#     LogP: 0.02 ± 1.01
#     TPSA: 41.44 ± 24.29
#     Molecular Weight: 119.4 ± 10.0
#   Cluster 1120 (n=12):
#     LogP: 0.06 ± 0.68
#     TPSA: 45.01 ± 16.24
#     Molecular Weight: 122.9 ± 5.6
#   Cluster 1121 (n=6):
#     LogP: 0.20 ± 0.56
#     TPSA: 38.15 ± 7.91
#     Molecular Weight: 120.6 ± 8.0
#   Cluster 1122 (n=24):
#     LogP: 0.22 ± 1.28
#     TPSA: 40.85 ± 23.50
#     Molecular Weight: 124.3 ± 6.6
#   Cluster 1123 (n=7):
#     LogP: 0.07 ± 0.86
#     TPSA: 36.24 ± 26.07
#     Molecular Weight: 124.9 ± 3.9
#   Cluster 1124 (n=6):
#     LogP: -0.11 ± 1.09
#     TPSA: 41.67 ± 20.78
#     Molecular Weight: 122.8 ± 8.3
#   Cluster 1125 (n=9):
#     LogP: 0.39 ± 1.04
#     TPSA: 39.36 ± 23.07
#     Molecular Weight: 123.5 ± 7.0
#   Cluster 1126 (n=8):
#     LogP: 0.69 ± 0.88
#     TPSA: 28.77 ± 17.27
#     Molecular Weight: 118.7 ± 10.9
#   Cluster 1127 (n=9):
#     LogP: 0.67 ± 0.74
#     TPSA: 32.57 ± 13.73
#     Molecular Weight: 123.0 ± 6.1
#   Cluster 1128 (n=7):
#     LogP: 0.61 ± 0.93
#     TPSA: 24.13 ± 12.21
#     Molecular Weight: 123.2 ± 5.4
#   Cluster 1129 (n=18):
#     LogP: 0.19 ± 0.99
#     TPSA: 35.43 ± 18.72
#     Molecular Weight: 118.0 ± 17.3
#   Cluster 1130 (n=25):
#     LogP: 0.32 ± 1.15
#     TPSA: 38.49 ± 21.88
#     Molecular Weight: 121.5 ± 9.6
#   Cluster 1131 (n=11):
#     LogP: 0.62 ± 0.97
#     TPSA: 37.17 ± 22.10
#     Molecular Weight: 123.7 ± 8.9
#   Cluster 1132 (n=18):
#     LogP: 0.31 ± 0.68
#     TPSA: 37.47 ± 18.89
#     Molecular Weight: 123.4 ± 6.0
#   Cluster 1133 (n=10):
#     LogP: -0.01 ± 0.78
#     TPSA: 47.34 ± 17.23
#     Molecular Weight: 123.1 ± 6.8
#   Cluster 1134 (n=6):
#     LogP: 0.27 ± 1.03
#     TPSA: 39.45 ± 21.67
#     Molecular Weight: 123.8 ± 7.0
#   Cluster 1135 (n=9):
#     LogP: 0.10 ± 1.20
#     TPSA: 36.38 ± 18.09
#     Molecular Weight: 126.5 ± 2.3
#   Cluster 1136 (n=6):
#     LogP: -0.05 ± 1.38
#     TPSA: 37.80 ± 16.35
#     Molecular Weight: 125.5 ± 3.5
#   Cluster 1137 (n=12):
#     LogP: 0.38 ± 1.09
#     TPSA: 40.74 ± 26.82
#     Molecular Weight: 122.1 ± 5.6
#   Cluster 1138 (n=14):
#     LogP: 0.39 ± 0.67
#     TPSA: 29.33 ± 23.23
#     Molecular Weight: 116.9 ± 11.4
#   Cluster 1139 (n=9):
#     LogP: 0.44 ± 0.95
#     TPSA: 35.76 ± 25.71
#     Molecular Weight: 124.3 ± 7.7
#   Cluster 1140 (n=18):
#     LogP: 0.22 ± 0.90
#     TPSA: 37.20 ± 15.54
#     Molecular Weight: 121.2 ± 7.4
#   Cluster 1141 (n=16):
#     LogP: 0.04 ± 0.80
#     TPSA: 39.01 ± 20.80
#     Molecular Weight: 123.4 ± 6.4
#   Cluster 1142 (n=9):
#     LogP: -0.28 ± 1.53
#     TPSA: 46.16 ± 29.08
#     Molecular Weight: 120.9 ± 11.1
#   Cluster 1143 (n=17):
#     LogP: 0.21 ± 1.01
#     TPSA: 40.91 ± 25.02
#     Molecular Weight: 123.7 ± 5.7
#   Cluster 1144 (n=11):
#     LogP: 0.71 ± 0.83
#     TPSA: 26.89 ± 20.17
#     Molecular Weight: 124.7 ± 3.2
#   Cluster 1145 (n=6):
#     LogP: 0.36 ± 0.74
#     TPSA: 41.94 ± 22.42
#     Molecular Weight: 126.1 ± 2.1
#   Cluster 1146 (n=7):
#     LogP: 0.84 ± 0.72
#     TPSA: 28.29 ± 16.07
#     Molecular Weight: 122.0 ± 5.7
#   Cluster 1147 (n=5):
#     LogP: 0.33 ± 1.45
#     TPSA: 37.71 ± 19.56
#     Molecular Weight: 125.2 ± 4.3
#   Cluster 1148 (n=10):
#     LogP: 0.80 ± 0.74
#     TPSA: 28.98 ± 13.04
#     Molecular Weight: 120.5 ± 12.2
#   Cluster 1149 (n=13):
#     LogP: 0.38 ± 0.99
#     TPSA: 37.07 ± 21.22
#     Molecular Weight: 118.3 ± 16.9
#   Cluster 1150 (n=10):
#     LogP: 0.84 ± 0.99
#     TPSA: 32.81 ± 19.63
#     Molecular Weight: 126.7 ± 6.0
#   Cluster 1151 (n=11):
#     LogP: 0.39 ± 0.90
#     TPSA: 32.77 ± 18.10
#     Molecular Weight: 121.5 ± 9.1
#   Cluster 1152 (n=7):
#     LogP: 0.72 ± 0.63
#     TPSA: 31.32 ± 20.52
#     Molecular Weight: 123.6 ± 5.5
#   Cluster 1153 (n=6):
#     LogP: -0.12 ± 1.34
#     TPSA: 43.83 ± 15.07
#     Molecular Weight: 128.5 ± 3.2
#   Cluster 1154 (n=8):
#     LogP: 0.14 ± 0.71
#     TPSA: 39.17 ± 12.62
#     Molecular Weight: 126.9 ± 3.1
#   Cluster 1155 (n=6):
#     LogP: 0.12 ± 0.56
#     TPSA: 44.41 ± 21.44
#     Molecular Weight: 124.5 ± 6.0
#   Cluster 1156 (n=12):
#     LogP: 0.13 ± 1.76
#     TPSA: 48.76 ± 30.15
#     Molecular Weight: 122.7 ± 7.7
#   Cluster 1157 (n=13):
#     LogP: 0.31 ± 0.92
#     TPSA: 31.19 ± 14.62
#     Molecular Weight: 122.8 ± 7.6
#   Cluster 1158 (n=20):
#     LogP: 0.13 ± 0.94
#     TPSA: 43.20 ± 22.97
#     Molecular Weight: 121.7 ± 10.9
#   Cluster 1159 (n=13):
#     LogP: 0.44 ± 0.84
#     TPSA: 36.11 ± 17.01
#     Molecular Weight: 122.8 ± 4.4
#   Cluster 1160 (n=16):
#     LogP: 0.81 ± 1.00
#     TPSA: 33.70 ± 23.43
#     Molecular Weight: 120.8 ± 9.3
#   Cluster 1161 (n=7):
#     LogP: 0.43 ± 0.96
#     TPSA: 35.61 ± 23.30
#     Molecular Weight: 124.4 ± 3.9
#   Cluster 1162 (n=15):
#     LogP: 0.54 ± 0.85
#     TPSA: 34.55 ± 18.05
#     Molecular Weight: 119.5 ± 11.9
#   Cluster 1163 (n=6):
#     LogP: -0.22 ± 1.16
#     TPSA: 55.91 ± 25.07
#     Molecular Weight: 123.6 ± 5.3
#   Cluster 1164 (n=7):
#     LogP: -0.47 ± 1.19
#     TPSA: 42.82 ± 31.08
#     Molecular Weight: 125.4 ± 4.2
#   Cluster 1165 (n=15):
#     LogP: 0.68 ± 1.10
#     TPSA: 29.05 ± 21.34
#     Molecular Weight: 123.3 ± 6.1
#   Cluster 1166 (n=9):
#     LogP: 0.33 ± 0.78
#     TPSA: 32.14 ± 13.45
#     Molecular Weight: 124.0 ± 5.8
#   Cluster 1167 (n=11):
#     LogP: 0.72 ± 0.89
#     TPSA: 31.60 ± 20.48
#     Molecular Weight: 120.2 ± 9.4
#   Cluster 1168 (n=9):
#     LogP: 0.79 ± 0.92
#     TPSA: 22.16 ± 20.28
#     Molecular Weight: 116.8 ± 6.2
#   Cluster 1169 (n=8):
#     LogP: 0.38 ± 0.88
#     TPSA: 31.28 ± 18.49
#     Molecular Weight: 112.6 ± 19.5
#   Cluster 1170 (n=17):
#     LogP: 0.03 ± 0.70
#     TPSA: 40.54 ± 17.42
#     Molecular Weight: 123.4 ± 5.7
#   Cluster 1171 (n=13):
#     LogP: 0.30 ± 1.29
#     TPSA: 31.17 ± 17.61
#     Molecular Weight: 123.4 ± 5.6
#   Cluster 1172 (n=15):
#     LogP: 0.15 ± 0.96
#     TPSA: 38.64 ± 16.67
#     Molecular Weight: 122.8 ± 8.9
#   Cluster 1173 (n=7):
#     LogP: 0.27 ± 0.99
#     TPSA: 33.51 ± 13.65
#     Molecular Weight: 121.3 ± 6.1
#   Cluster 1174 (n=15):
#     LogP: 0.27 ± 0.86
#     TPSA: 44.66 ± 16.10
#     Molecular Weight: 123.2 ± 7.9
#   Cluster 1175 (n=12):
#     LogP: -0.10 ± 0.94
#     TPSA: 43.60 ± 24.30
#     Molecular Weight: 120.6 ± 8.8
#   Cluster 1176 (n=10):
#     LogP: 0.83 ± 1.09
#     TPSA: 28.73 ± 19.31
#     Molecular Weight: 123.7 ± 4.8
#   Cluster 1177 (n=8):
#     LogP: -0.08 ± 1.01
#     TPSA: 41.83 ± 18.60
#     Molecular Weight: 127.8 ± 3.3
#   Cluster 1178 (n=23):
#     LogP: 0.91 ± 0.99
#     TPSA: 25.13 ± 18.00
#     Molecular Weight: 121.1 ± 9.9
#   Cluster 1179 (n=14):
#     LogP: 0.44 ± 1.08
#     TPSA: 36.61 ± 25.71
#     Molecular Weight: 117.4 ± 8.1
#   Cluster 1180 (n=6):
#     LogP: -0.18 ± 0.77
#     TPSA: 40.86 ± 29.99
#     Molecular Weight: 122.3 ± 5.3
#   Cluster 1181 (n=6):
#     LogP: -0.01 ± 0.56
#     TPSA: 47.26 ± 11.73
#     Molecular Weight: 121.3 ± 5.6
#   Cluster 1182 (n=11):
#     LogP: -0.39 ± 0.44
#     TPSA: 47.20 ± 16.18
#     Molecular Weight: 122.9 ± 6.7
#   Cluster 1183 (n=5):
#     LogP: 0.34 ± 1.09
#     TPSA: 45.79 ± 42.91
#     Molecular Weight: 111.3 ± 17.9
#   Cluster 1184 (n=7):
#     LogP: 0.59 ± 0.78
#     TPSA: 24.79 ± 9.05
#     Molecular Weight: 122.0 ± 6.3
#   Cluster 1185 (n=12):
#     LogP: 0.21 ± 1.15
#     TPSA: 41.12 ± 25.53
#     Molecular Weight: 121.5 ± 9.1
#   Cluster 1186 (n=8):
#     LogP: -0.32 ± 0.56
#     TPSA: 39.47 ± 18.34
#     Molecular Weight: 124.4 ± 4.7
#   Cluster 1187 (n=5):
#     LogP: 0.40 ± 1.08
#     TPSA: 27.80 ± 22.32
#     Molecular Weight: 123.4 ± 6.9
#   Cluster 1188 (n=10):
#     LogP: -0.20 ± 0.79
#     TPSA: 47.75 ± 18.16
#     Molecular Weight: 121.9 ± 10.7
#   Cluster 1189 (n=7):
#     LogP: 0.56 ± 1.16
#     TPSA: 39.75 ± 23.51
#     Molecular Weight: 124.2 ± 7.5
#   Cluster 1190 (n=52):
#     LogP: 0.44 ± 1.04
#     TPSA: 34.42 ± 19.15
#     Molecular Weight: 122.6 ± 7.2
#   Cluster 1191 (n=12):
#     LogP: -0.11 ± 0.91
#     TPSA: 45.22 ± 21.16
#     Molecular Weight: 124.7 ± 5.4
#   Cluster 1192 (n=16):
#     LogP: -0.03 ± 0.86
#     TPSA: 42.28 ± 20.81
#     Molecular Weight: 123.7 ± 6.4
#   Cluster 1193 (n=13):
#     LogP: 0.49 ± 1.09
#     TPSA: 43.12 ± 22.30
#     Molecular Weight: 123.8 ± 4.1
#   Cluster 1194 (n=8):
#     LogP: -0.28 ± 0.87
#     TPSA: 47.96 ± 15.49
#     Molecular Weight: 124.8 ± 10.8
#   Cluster 1195 (n=12):
#     LogP: 0.01 ± 1.18
#     TPSA: 41.31 ± 25.38
#     Molecular Weight: 123.7 ± 9.5
#   Cluster 1196 (n=11):
#     LogP: 0.42 ± 0.88
#     TPSA: 44.50 ± 26.51
#     Molecular Weight: 123.3 ± 4.5
#   Cluster 1197 (n=6):
#     LogP: 0.96 ± 0.65
#     TPSA: 25.98 ± 18.31
#     Molecular Weight: 122.0 ± 6.7
#   Cluster 1198 (n=12):
#     LogP: 0.53 ± 1.24
#     TPSA: 30.08 ± 19.83
#     Molecular Weight: 123.9 ± 5.9
#   Cluster 1199 (n=13):
#     LogP: 0.43 ± 0.91
#     TPSA: 37.09 ± 21.87
#     Molecular Weight: 118.1 ± 9.5
#   Cluster 1200 (n=16):
#     LogP: 0.79 ± 0.96
#     TPSA: 30.71 ± 21.73
#     Molecular Weight: 124.7 ± 4.9
#   Cluster 1201 (n=9):
#     LogP: 0.10 ± 0.90
#     TPSA: 37.35 ± 17.06
#     Molecular Weight: 118.8 ± 10.0
#   Cluster 1202 (n=5):
#     LogP: 0.50 ± 0.72
#     TPSA: 32.90 ± 18.10
#     Molecular Weight: 123.8 ± 8.3
#   Cluster 1203 (n=15):
#     LogP: 0.01 ± 0.82
#     TPSA: 40.29 ± 17.60
#     Molecular Weight: 124.9 ± 5.1
#   Cluster 1204 (n=17):
#     LogP: 0.15 ± 1.19
#     TPSA: 46.21 ± 19.07
#     Molecular Weight: 124.7 ± 5.0
#   Cluster 1205 (n=6):
#     LogP: -0.47 ± 0.70
#     TPSA: 63.16 ± 15.74
#     Molecular Weight: 119.3 ± 10.9
#   Cluster 1206 (n=6):
#     LogP: 0.31 ± 1.22
#     TPSA: 39.76 ± 14.87
#     Molecular Weight: 126.1 ± 3.8
#   Cluster 1207 (n=6):
#     LogP: -0.11 ± 0.59
#     TPSA: 40.16 ± 13.89
#     Molecular Weight: 118.5 ± 14.0
#   Cluster 1208 (n=15):
#     LogP: 0.23 ± 0.44
#     TPSA: 38.31 ± 15.99
#     Molecular Weight: 123.1 ± 6.6
#   Cluster 1209 (n=10):
#     LogP: 0.23 ± 0.60
#     TPSA: 45.98 ± 20.26
#     Molecular Weight: 120.7 ± 10.6
#   Cluster 1210 (n=15):
#     LogP: 0.38 ± 0.90
#     TPSA: 32.23 ± 14.24
#     Molecular Weight: 126.0 ± 4.9
#   Cluster 1211 (n=11):
#     LogP: 0.38 ± 0.90
#     TPSA: 37.29 ± 21.70
#     Molecular Weight: 122.3 ± 6.8
#   Cluster 1212 (n=8):
#     LogP: 0.77 ± 0.86
#     TPSA: 31.06 ± 17.30
#     Molecular Weight: 123.2 ± 6.8
#   Cluster 1213 (n=9):
#     LogP: 0.24 ± 1.02
#     TPSA: 29.50 ± 19.69
#     Molecular Weight: 116.5 ± 13.3
#   Cluster 1214 (n=9):
#     LogP: 0.21 ± 1.17
#     TPSA: 46.16 ± 26.23
#     Molecular Weight: 121.5 ± 7.0
#   Cluster 1215 (n=18):
#     LogP: 0.12 ± 1.06
#     TPSA: 32.87 ± 20.22
#     Molecular Weight: 122.0 ± 7.7
#   Cluster 1216 (n=6):
#     LogP: 0.73 ± 1.29
#     TPSA: 34.79 ± 23.94
#     Molecular Weight: 124.7 ± 5.9
#   Cluster 1217 (n=13):
#     LogP: 0.51 ± 0.89
#     TPSA: 29.17 ± 13.98
#     Molecular Weight: 125.9 ± 3.8
#   Cluster 1218 (n=6):
#     LogP: 0.36 ± 0.69
#     TPSA: 39.10 ± 14.67
#     Molecular Weight: 124.3 ± 3.1
#   Cluster 1219 (n=11):
#     LogP: -0.43 ± 1.37
#     TPSA: 40.36 ± 23.90
#     Molecular Weight: 123.1 ± 6.1
#   Cluster 1220 (n=14):
#     LogP: 0.42 ± 0.56
#     TPSA: 33.41 ± 13.56
#     Molecular Weight: 124.9 ± 4.8
#   Cluster 1221 (n=12):
#     LogP: 0.10 ± 0.85
#     TPSA: 42.83 ± 12.02
#     Molecular Weight: 117.5 ± 16.9
#   Cluster 1222 (n=7):
#     LogP: 1.14 ± 0.62
#     TPSA: 17.57 ± 13.93
#     Molecular Weight: 123.5 ± 2.8
#   Cluster 1223 (n=13):
#     LogP: 0.52 ± 1.11
#     TPSA: 31.46 ± 25.74
#     Molecular Weight: 121.2 ± 7.7
#   Cluster 1224 (n=6):
#     LogP: 0.53 ± 1.20
#     TPSA: 23.64 ± 10.80
#     Molecular Weight: 118.0 ± 12.2
#   Cluster 1225 (n=6):
#     LogP: 0.53 ± 1.07
#     TPSA: 43.95 ± 22.10
#     Molecular Weight: 123.3 ± 6.8
#   Cluster 1226 (n=7):
#     LogP: -0.02 ± 1.02
#     TPSA: 42.19 ± 20.44
#     Molecular Weight: 121.4 ± 6.8
#   Cluster 1227 (n=9):
#     LogP: 0.50 ± 0.83
#     TPSA: 36.15 ± 25.36
#     Molecular Weight: 124.1 ± 6.6
#   Cluster 1228 (n=9):
#     LogP: -0.29 ± 0.92
#     TPSA: 50.52 ± 25.90
#     Molecular Weight: 125.0 ± 6.4
#   Cluster 1229 (n=7):
#     LogP: 1.18 ± 0.96
#     TPSA: 24.26 ± 16.30
#     Molecular Weight: 124.7 ± 1.5
#   Cluster 1230 (n=7):
#     LogP: 0.91 ± 0.96
#     TPSA: 27.94 ± 18.66
#     Molecular Weight: 122.9 ± 13.1
#   Cluster 1231 (n=8):
#     LogP: 0.40 ± 0.97
#     TPSA: 36.80 ± 16.14
#     Molecular Weight: 124.2 ± 5.2
#   Cluster 1232 (n=15):
#     LogP: 0.03 ± 0.99
#     TPSA: 44.14 ± 17.53
#     Molecular Weight: 121.5 ± 9.9
#   Cluster 1233 (n=13):
#     LogP: 0.17 ± 1.01
#     TPSA: 42.20 ± 23.47
#     Molecular Weight: 125.6 ± 2.9
#   Cluster 1234 (n=8):
#     LogP: 0.33 ± 1.01
#     TPSA: 34.34 ± 27.91
#     Molecular Weight: 115.3 ± 19.3
#   Cluster 1235 (n=5):
#     LogP: 0.02 ± 0.68
#     TPSA: 41.29 ± 13.94
#     Molecular Weight: 124.9 ± 4.0
#   Cluster 1236 (n=18):
#     LogP: 0.63 ± 0.89
#     TPSA: 29.55 ± 20.55
#     Molecular Weight: 119.8 ± 9.3
#   Cluster 1237 (n=7):
#     LogP: 0.34 ± 1.30
#     TPSA: 38.17 ± 37.98
#     Molecular Weight: 123.6 ± 6.1
#   Cluster 1238 (n=7):
#     LogP: -0.31 ± 0.89
#     TPSA: 51.24 ± 26.04
#     Molecular Weight: 121.3 ± 5.9
#
# Clustering results exported to: qm9_clustering_results.csv
#
# Analysis completed successfully!
# Dataset contains 133885 molecules with molecular descriptors and cluster assignments.

# %% [markdown]
# ### **9. DBSCAN Clustering with Parameter Optimization**
#
# Apply DBSCAN (Density-Based Spatial Clustering) with comprehensive parameter optimization for epsilon and min_samples. DBSCAN is different from HDBSCAN as it uses a fixed epsilon radius rather than hierarchical density estimation.

# %%
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np


# DBSCAN Parameter Grid Search
# Epsilon values - determine neighborhood radius
eps_values = [0.3, 0.5, 0.7, 1.0, 1.2, 1.5, 2.0]
# Min_samples values - minimum points to form dense region
min_samples_values = [3, 5, 7, 10, 15, 20]

dbscan_results = []
best_dbscan_score = -1
best_dbscan_params = {}

print(f"\nTesting {len(eps_values)} epsilon values × {len(min_samples_values)} min_samples values = {len(eps_values) * len(min_samples_values)} combinations")

# Parameter optimization
for eps in tqdm(eps_values, desc="DBSCAN optimization"):
    for min_samples in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric='euclidean', n_jobs=-1)
        dbscan_labels = dbscan.fit_predict(features_sample)
        
        n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
        n_noise = list(dbscan_labels).count(-1)
        
        if n_clusters > 1:  # Need at least 2 clusters for evaluation
            try:
                # Calculate silhouette score for non-noise points only
                valid_mask = dbscan_labels != -1
                if np.sum(valid_mask) > 1:
                    sil_score = silhouette_score(features_sample[valid_mask], dbscan_labels[valid_mask])
                    calinski_score = calinski_harabasz_score(features_sample[valid_mask], dbscan_labels[valid_mask])
                    
                    dbscan_results.append({
                        'eps': eps,
                        'min_samples': min_samples,
                        'n_clusters': n_clusters,
                        'n_noise': n_noise,
                        'noise_ratio': n_noise / len(dbscan_labels),
                        'silhouette': sil_score,
                        'calinski_harabasz': calinski_score
                    })
                    
                    # Select best parameters based on silhouette score
                    if sil_score > best_dbscan_score:
                        best_dbscan_score = sil_score
                        best_dbscan_params = {'eps': eps, 'min_samples': min_samples}
            except:
                continue

# Convert results to DataFrame for analysis
dbscan_results_df = pl.DataFrame(dbscan_results).to_pandas()
print(f"\nDBSCAN Parameter Optimization Results:")
print(dbscan_results_df.round(3))

if best_dbscan_params:
    print(f"\nBest DBSCAN parameters:")
    print(f"  Epsilon: {best_dbscan_params['eps']}")
    print(f"  Min_samples: {best_dbscan_params['min_samples']}")
    print(f"  Best silhouette score: {best_dbscan_score:.3f}")
    
    # Apply DBSCAN with best parameters
    dbscan_final = DBSCAN(eps=best_dbscan_params['eps'], 
                         min_samples=best_dbscan_params['min_samples'], 
                         metric='euclidean', n_jobs=-1)
    dbscan_labels_sample = dbscan_final.fit_predict(features_sample)
    
    # Add DBSCAN results to sample dataframe
    scaled_df_sample['dbscan_cluster'] = dbscan_labels_sample
    
    # Analyze DBSCAN results
    n_clusters_dbscan = len(set(dbscan_labels_sample)) - (1 if -1 in dbscan_labels_sample else 0)
    n_noise_dbscan = list(dbscan_labels_sample).count(-1)
    
    print(f"\nDBSCAN Final Results (sample of {sample_size} molecules):")
    print(f"  Number of clusters: {n_clusters_dbscan}")
    print(f"  Number of noise points: {n_noise_dbscan}")
    print(f"  Noise percentage: {(n_noise_dbscan/len(dbscan_labels_sample))*100:.1f}%")
    
    # Cluster distribution
    unique_clusters, cluster_counts = np.unique(dbscan_labels_sample, return_counts=True)
    cluster_counts_dict = dict(zip(unique_clusters, cluster_counts))
    print(f"\n  Cluster distribution:")
    for cluster, count in cluster_counts_dict.items():
        percentage = (count / len(dbscan_labels_sample)) * 100
        if cluster == -1:
            print(f"    Noise: {count} molecules ({percentage:.1f}%)")
        else:
            print(f"    Cluster {cluster}: {count} molecules ({percentage:.1f}%)")
            
    # Calculate final metrics
    if n_clusters_dbscan > 1:
        valid_mask = dbscan_labels_sample != -1
        if np.sum(valid_mask) > 1:
            dbscan_silhouette = silhouette_score(features_sample[valid_mask], dbscan_labels_sample[valid_mask])
            dbscan_calinski = calinski_harabasz_score(features_sample[valid_mask], dbscan_labels_sample[valid_mask])
            
            print(f"\n  Final DBSCAN Metrics:")
            print(f"    Silhouette Score: {dbscan_silhouette:.3f}")
            print(f"    Calinski-Harabasz Score: {dbscan_calinski:.3f}")
else:
    print("\n⚠ No valid DBSCAN parameters found. Using fallback parameters.")
    dbscan_final = DBSCAN(eps=1.0, min_samples=5, metric='euclidean')
    dbscan_labels_sample = dbscan_final.fit_predict(features_sample)
    scaled_df_sample['dbscan_cluster'] = dbscan_labels_sample
    n_clusters_dbscan = len(set(dbscan_labels_sample)) - (1 if -1 in dbscan_labels_sample else 0)
    n_noise_dbscan = list(dbscan_labels_sample).count(-1)
# Out:
# Testing 7 epsilon values × 6 min_samples values = 42 combinations
# DBSCAN optimization: 100%|██████████| 7/7 [01:20<00:00, 11.49s/it]
# DBSCAN Parameter Optimization Results:
#     eps  min_samples  n_clusters  n_noise  noise_ratio  silhouette  \
# 0   0.3            3         590     2575        0.129       0.162
# 1   0.3            5         292     3822        0.191       0.211
# 2   0.3            7         201     4746        0.237       0.252
# 3   0.3           10         138     5866        0.293       0.302
# 4   0.3           15          90     7413        0.371       0.354
# 5   0.3           20          68     8716        0.436       0.360
# 6   0.5            3         310      887        0.044       0.222
# 7   0.5            5         199     1377        0.069       0.238
# 8   0.5            7         150     1800        0.090       0.246
# 9   0.5           10         135     2288        0.114       0.260
# 10  0.5           15          95     3211        0.161       0.274
# 11  0.5           20          75     3916        0.196       0.281
# 12  0.7            3         240      452        0.023       0.204
# 13  0.7            5         176      717        0.036       0.205
# 14  0.7            7         142      979        0.049       0.206
# 15  0.7           10         118     1313        0.066       0.208
# 16  0.7           15          89     1840        0.092       0.216
# 17  0.7           20          70     2363        0.118       0.224
# 18  1.0            3          35      144        0.007       0.010
# 19  1.0            5          14      245        0.012       0.048
# 20  1.0            7          12      341        0.017       0.093
# 21  1.0           10          11      434        0.022       0.058
# 22  1.0           15           7      629        0.031       0.106
# 23  1.0           20           7      791        0.040       0.104
# 24  1.2            3           8       65        0.003       0.294
# 25  1.2            5           7       92        0.005       0.283
# 26  1.2            7           2      131        0.007       0.563
# 27  1.2           10           2      167        0.008       0.235
# 28  1.2           15           2      249        0.012       0.386
# 29  1.2           20           2      345        0.017       0.471
#
#     calinski_harabasz
# 0             393.676
# 1             667.727
# 2             869.365
# 3            1130.133
# 4            1524.142
# 5            1807.328
# 6             464.819
# 7             665.173
# 8             835.469
# 9             972.243
# 10           1275.950
# 11           1497.488
# 12            468.108
# 13            603.499
# 14            720.681
# 15            840.013
# 16           1056.878
# 17           1307.689
# 18            332.525
# 19            827.773
# 20            986.241
# 21           1080.467
# 22           1789.166
# 23           1759.958
# 24             34.355
# 25             29.100
# 26             59.670
# 27             17.062
# 28            122.554
# 29            113.977
#
# Best DBSCAN parameters:
#   Epsilon: 1.2
#   Min_samples: 7
#   Best silhouette score: 0.563
#
# DBSCAN Final Results (sample of 20000 molecules):
#   Number of clusters: 2
#   Number of noise points: 131
#   Noise percentage: 0.7%
#
#   Cluster distribution:
#     Noise: 131 molecules (0.7%)
#     Cluster 0: 19862 molecules (99.3%)
#     Cluster 1: 7 molecules (0.0%)
#
# DBSCAN Final Results (sample of 20000 molecules):
#   Number of clusters: 2
#   Number of noise points: 131
#   Noise percentage: 0.7%
#
#   Cluster distribution:
#     Noise: 131 molecules (0.7%)
#     Cluster 0: 19862 molecules (99.3%)
#     Cluster 1: 7 molecules (0.0%)
#
#   Final DBSCAN Metrics:
#     Silhouette Score: 0.563
#     Calinski-Harabasz Score: 59.670
#
#   Final DBSCAN Metrics:
#     Silhouette Score: 0.563
#     Calinski-Harabasz Score: 59.670
